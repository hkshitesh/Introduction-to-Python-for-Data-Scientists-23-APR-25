# %% [markdown]
# # **Understanding Python Error Types**
#
# ---
#
#
# Errors in Python occur when the interpreter encounters something it cannot execute. Errors can be caused by syntax mistakes, incorrect operations, missing variables, or invalid inputs.

# %% [markdown]
# # **1. SyntaxError**
#
# ---
#
#
# A SyntaxError happens when the Python interpreter finds incorrect syntax in the code.

# %%
if True
    print("Hello")
# Out:
#   File "<ipython-input-1-c327b5a22856>", line 1
#     if True
#            ^
# SyntaxError: expected ':'

# %% [markdown]
# Solution:
#
# ---
#
#
#
#
# Correct the syntax.

# %%
if True:
    print("Hello")
# Out:
# Hello

# %% [markdown]
# # **2. IndexError**
#
# ---
#
#
# Occurs when trying to access an element from a list or tuple using an invalid index.

# %%
my_list = [1, 2, 3]
print(my_list[5])  # No index 5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-f773369d8b7a> in <cell line: 0>()
#       1 my_list = [1, 2, 3]
# ----> 2 print(my_list[5])  # No index 5
#
# IndexError: list index out of range

# %% [markdown]
# Solution:
#
# Ensure the index is within range.

# %%
if len(my_list) > 5:
    print(my_list[5])
else:
    print("Index out of range.")
# Out:
# Index out of range.

# %% [markdown]
# # **3. NameError**
#
# ---
#
#
# Happens when a variable or function is used before being defined.
#
# Example:

# %%
print(my_variable)  # Variable not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-aeb564c93e86> in <cell line: 0>()
# ----> 1 print(my_variable)  # Variable not defined
#
# NameError: name 'my_variable' is not defined

# %% [markdown]
# Solution:
#
# Define the variable before using it.

# %%
my_variable = "Hello"
print(my_variable)
# Out:
# Hello

# %% [markdown]
# # **4. TypeError**
#
# ---
#
#
# Occurs when an operation is performed on an incorrect data type.
#
# Example:

# %%
num = str(10) + "hello"  # Cannot add int and string

# %%
print(num)
# Out:
# 10hello

# %% [markdown]
# Solution:
#
# Convert types explicitly before operations.

# %%
num = 10 + int("5")
num
# Out:
# 15

# %% [markdown]
# # **5. ValueError**
#
# ---
#
#
# Occurs when a function receives an argument of the correct type but an invalid value.
# Example:

# %%
num = int("abc")  # Cannot convert "abc" to an integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-657748e666e9> in <cell line: 0>()
# ----> 1 num = int("abc")  # Cannot convert "abc" to an integer
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# Solution:
#
# Validate input before conversion.

# %%
x="101"
if isinstance(x,int):
    num = int(x)
    print(num)
else:
    print("Invalid input")
# Out:
# Invalid input

# %% [markdown]
# # **6. KeyError**
#
# ---
#
#
# Occurs when trying to access a missing key in a dictionary.

# %%
my_dict = {"name": "Alice"}
print(my_dict["age"])  # Key "age" does not exist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-78f195f65929> in <cell line: 0>()
#       1 my_dict = {"name": "Alice"}
# ----> 2 print(my_dict["age"])  # Key "age" does not exist
#
# KeyError: 'age'

# %% [markdown]
# Solution:
#
# Use .get() to avoid errors.

# %%
print(my_dict.get("age", "Key not found"))
# Out:
# Key not found

# %% [markdown]
# # **7. AttributeError**
#
# ---
#
#
# Occurs when calling an attribute or method that does not exist on an object.
#
# Example:

# %%
num = 10
print(num.upper())  # Integers do not have an 'upper()' method
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-170b71008382> in <cell line: 0>()
#       1 num = 10
# ----> 2 print(num.upper())  # Integers do not have an 'upper()' method
#
# AttributeError: 'int' object has no attribute 'upper'

# %% [markdown]
# Solution:
#
# Check the object type before calling methods.

# %% [markdown]
# # **8. ZeroDivisionError**
#
# ---
#
#
# Occurs when dividing by zero.
#
# Example:

# %%
result = 10 / 0  # Division by zero

# %% [markdown]
# Solution:
#
# Check the divisor before division.

# %%
denominator = 0
if denominator != 0:
    result = 10 / denominator
else:
    print("Cannot divide by zero.")

# %% [markdown]
# # **9. ImportError**
#
# ---
#
#
# Occurs when importing a module that does not exist.
#
# Example:

# %%
import nonexistent_module  # Module does not exist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-9bdc828afaeb> in <cell line: 0>()
# ----> 1 import nonexistent_module  # Module does not exist
#
# ModuleNotFoundError: No module named 'nonexistent_module'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Solution:
#
# Ensure the module is installed before importing.

# %%
try:
    import numpy
except ImportError:
    print("Module not found, install it using 'pip install numpy'")
