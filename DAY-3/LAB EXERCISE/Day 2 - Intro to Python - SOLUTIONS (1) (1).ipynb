# %% [markdown]
# # Introduction to Python
#
# ## Day 2 - solutions

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: Functions</h1>
#
# 1. Define a function that calculates and returns the area of a circle based on its radius ($\pi r ^{2}$).

# %%
def area(radius):
    PI = 3.1415 # could also use the `math` module which has a built-in pi
    return PI * radius**2

area(14)
# Out:
# 615.734

# %% [markdown]
# 2. Define a function that calculates and returns **both** the area *and* the circumference ($2 \pi r$) of a circle based on its radius.

# %%
def circle_measurements(radius):
    PI = 3.1415

    # returning as a dictionary, but could be anything
    measurements = {
        "area": PI * radius**2,
        "circumference": 2 * PI * radius
    }

    return measurements

circle_measurements(14)
# Out:
# {'area': 615.734, 'circumference': 87.962}

# %% [markdown]
# 3. Define a function to calculate and return the **future value of a used car** based on its current value, a percentage depreciation value, and the number of years.
#
# The formula to use is $future\_value = current\_value \times (1 - depreciation\_rate)^{years}$
#
# e.g. a car worth 100,000 with 10% depreciation is worth 90,000 after 1 year, 81,000 in year 2, and 72,900 in year 3

# %%
def future_value(current_value, pct_depr, n_years):
    return current_value * ((1-pct_depr)**n_years)

future_value(100_000, 0.1, 3)
# Out:
# 72900.00000000001

# %% [markdown]
# 4. Define a function to calculate this same future value, but return **all intermediate values as a list**.
#
# For the previous example, a car worth 100,000 with 10% depreciation over 3 years should return `[90000, 81000, 72900]`

# %%
def future_values(current_value, pct_depr, n_years):
    values = []
    # go from year 1 up to (and including) n_years
    for year in range(1, n_years+1):
        year_value = current_value * ((1-pct_depr)**year)
        values.append(year_value)
    return values

future_values(100_000, 0.1, 3)
# Out:
# [90000.0, 81000.0, 72900.00000000001]

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: Function arguments</h1>
#
# 1. Write a function to check someone in at the airport. The inputs to the function should be the person's name, their date of birth, and then additional keyword arguments where they can specify document numbers (e.g. passport or national ID). Use `**kwargs` for this.
#
# The function should print a message saying the user has successfully checked in **only** if they provided a passport number OR a national ID number. Check the contents of `kwargs` for these inside the function.
#
# The function usage should be something like this:
#
# ```python
# check_in(name="David", dob="1970-01-01", passport_number="123")
# ```
#
# and an unsuccessful check in looks like this (no document IDs provided):
#
# ```python
# check_in(name="David", dob="1970-01-01")
# ```

# %%
def check_in(name, dob, **kwargs):
    if name != "" and dob != "" and (("passport_number" in kwargs) or ("national_id_number" in kwargs)):
        print("Checked in fine!")
    else:
        print("Some details are missing...")

check_in(name="David", dob="1970-01-01", passport_number="123")
check_in(name="David", dob="1970-01-01")
# Out:
# Checked in fine!
# Some details are missing...

# %% [markdown]
# 2. Write a function to validate that all *positional* arguments passed in are numeric. Use `*args` for this and check the values inside `args` one at a time. The function should print a success message if all the arguments passed in are numeric.
#
# To keep things simple, we'll assume anything that's an `int` or a `float` is numeric, otherwise it's not.
#
# In Python, to check if an object is a certain type, use `isinstance`:
#
# ```python
# isinstance(1, int) # this is True
# isinstance("1", float) # this is False
# ```

# %%
def validate_numeric(*args):
    for value in args:
        if isinstance(value, int) == False and isinstance(value, float) == False:
            print(f"Encountered invalid value {value}. Exiting...")
            return
    # we only get here if no issues encountered
    print("Values all fine")

validate_numeric(1, 2, 3, 4, 5)
# Out:
# Values all fine

# %%
validate_numeric(1, 2, 3, "4", 5)
# Out:
# Encountered invalid value 4. Exiting...

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: Secret santa</h1>
#
# Let's use everything we've learned so far to create a Secret Santa tool.
#
# Secret Santa is where people put their names in a hat, then everyone draws a name. The name they draw is the person they secretly buy a present for.
#
# #### Rules
#
# - everyone only has one secret santa
# - a person cannot be their own secret santa
# - the number of participants must be greater than 2
#
# #### Output
#
# The tool should be a single function which:
#
# - takes in a list of names
# - outputs the secret santa pairings while observing the above rules
# - there should be one item in the output for each name supplied, because everyone is assigned someone to buy a present for
#
# Outputs can be anything: tuples, a list of lists, a dictionary, or even just printed messages.
#
# For example, a list like `["David", "Jeff", "Alice", "Martha"]` could produce a list like:
#
# `[("David", "Jeff"), ("Jeff", "Martha"), ("Alice", "David"), ("Martha", "Alice")]`
#
# #### Optional bonuses
#
# - allow for any number of participants
# - error handling (print error messages if any of the above rules are broken)
#
# *Hint: as always, break down the problem into small pieces. Start with the function definition, then write out the logic in plain English using comments to clarify the process in your mind, then fill in the blanks with Python code*

# %%
import random

def secret_santa(names):
    if len(names) < 3:
        print("You need at least 3 names for secret santa!")
        return

    # let's start with randomly shuffling the list, looping through each user,
    # assigning them their partner to buy a gift for, ensuring we select everyone only once

    # make a list of pairs to remove from whenever we assign a pair
    # and this way we don't affect the original list
    pairs = names.copy()

    random.shuffle(names)

    pairings = []

    for name in names:
        # in case the first name in the pairs list is this person
        if pairs[0] == name:
            pair = pairs[1]
        else:
            pair = pairs[0]

        pairings.append((name, pair))

        # now remove that person from being a pair again
        pairs.remove(pair)

    return pairings

secret_santa(["David", "Alice", "Jeff", "Martha"])
# Out:
# [('Alice', 'David'),
#  ('David', 'Alice'),
#  ('Jeff', 'Martha'),
#  ('Martha', 'Jeff')]

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: The Standard Library</h1>
#
# Time to practise using some of the standard library!
#
# 1. "Unix time" is a measure of how much time has elapsed since the 1st of January, 1970. Use the `datetime` library to calculate how many days have elapsed in Unix time.

# %%
import datetime

elapsed = datetime.datetime.now() - datetime.datetime(1970, 1, 1)
print(type(elapsed))

elapsed.days
# Out:
# <class 'datetime.timedelta'>
# 19757

# %% [markdown]
# 2. There is a file in the `data` folder called `songs.json`, but how many songs does it contain?
#
# - Read its contents into a single string
# - Use the `json` module to convert the string to a Python object
# - Count the songs!

# %%
import json

song_string = ""

with open("data/songs.json", "r") as f:
    song_string = f.read()
song_json = json.loads(song_string)
print(len(song_json))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-51e8815b103f> in <cell line: 0>()
#       3 song_string = ""
#       4
# ----> 5 with open("data/songs.json", "r") as f:
#       6     song_string = f.read()
#       7 song_json = json.loads(song_string)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/songs.json'

# %% [markdown]
# 3. Investigate the `pprint` module to print a nice representation of the songs in the `songs.json` file.
#
# Experiment with the different options and compare how your result looks vs. simply printing the songs.

# %%
import pprint

pprint.pprint(song_json, indent=2, width=50)
# Out:
# [ { 'artistName': 'The Boomtown Rats',
#     'endTime': '2021-11-22 12:05',
#     'msPlayed': 259093,
#     'trackName': "I Don't Like Mondays"},
#   { 'artistName': 'The Darkness',
#     'endTime': '2021-11-22 12:09',
#     'msPlayed': 217653,
#     'trackName': 'I Believe in a Thing Called '
#                  'Love'},
#   { 'artistName': 'Meat Loaf',
#     'endTime': '2021-11-22 12:22',
#     'msPlayed': 508333,
#     'trackName': 'Paradise By the Dashboard '
#                  'Light'},
#   { 'artistName': 'Meat Loaf',
#     'endTime': '2021-11-22 12:38',
#     'msPlayed': 590000,
#     'trackName': 'Bat Out of Hell'},
#   { 'artistName': 'Sam Cooke',
#     'endTime': '2021-11-27 17:01',
#     'msPlayed': 157622,
#     'trackName': 'Chain Gang'},
#   { 'artistName': 'Steve Harley',
#     'endTime': '2021-11-27 17:05',
#     'msPlayed': 226776,
#     'trackName': 'Make Me Smile (Come up and See '
#                  'Me) - 2014 Remaster'},
#   { 'artistName': 'Maximo Park',
#     'endTime': '2021-11-29 11:36',
#     'msPlayed': 200346,
#     'trackName': 'Apply Some Pressure'},
#   { 'artistName': 'Sam Cooke',
#     'endTime': '2021-11-30 08:16',
#     'msPlayed': 160000,
#     'trackName': 'Chain Gang'},
#   { 'artistName': "Israel Kamakawiwo'ole",
#     'endTime': '2021-12-02 11:10',
#     'msPlayed': 211933,
#     'trackName': 'Over the Rainbow'},
#   { 'artistName': 'David Bowie',
#     'endTime': '2021-12-02 11:19',
#     'msPlayed': 274746,
#     'trackName': 'Rebel Rebel - 2016 Remaster'},
#   { 'artistName': 'The Specials',
#     'endTime': '2021-12-02 11:22',
#     'msPlayed': 172600,
#     'trackName': 'A Message to You Rudy - 2002 '
#                  'Remaster'},
#   { 'artistName': 'Derek & The Dominos',
#     'endTime': '2021-12-02 11:22',
#     'msPlayed': 4460,
#     'trackName': 'Layla'},
#   { 'artistName': 'Paul Simon',
#     'endTime': '2021-12-02 17:56',
#     'msPlayed': 291200,
#     'trackName': 'Graceland'},
#   { 'artistName': 'The Byrds',
#     'endTime': '2021-12-02 18:05',
#     'msPlayed': 229360,
#     'trackName': 'Turn! Turn! Turn! (To '
#                  'Everything There Is a Season)'},
#   { 'artistName': 'Stealers Wheel',
#     'endTime': '2021-12-02 18:06',
#     'msPlayed': 31401,
#     'trackName': 'Stuck In The Middle With You'},
#   { 'artistName': 'Noisettes',
#     'endTime': '2021-12-02 18:09',
#     'msPlayed': 192213,
#     'trackName': 'Never Forget You'}]

# %% [markdown]
# 4. Write a function that takes in the month number (1-12) and prints the name of the month.
#
# Look into the `calendar` module to help you.
#
# *Bonus: try doing this using the `datetime` module instead*

# %%
import calendar

def get_month_name(month_number):
    return calendar.month_name[month_number]

get_month_name(7)
# Out:
# 'July'

# %%
def get_month_name_dt(month_number):
    # create a date using the month number
    date = datetime.datetime(2024, month_number, 1)
    return date.strftime("%B")

get_month_name_dt(9)
# Out:
# 'September'

# %% [markdown]
# 5. Write a function that takes in a letter and tells you its position in the alphabet.
#
# Use the `string` module to help you, don't write out an alphabet yourself!

# %%
import string

def get_position(letter):
    letter_index = string.ascii_lowercase.find(letter.lower())
    # we should really return the letter's position as 1-indexed
    # so A is 1 not 0
    return letter_index + 1

print(get_position("a"),
      get_position("M"))
# Out:
# 1 13

# %% [markdown]
# 6. Use the `statistics` library to work out both the **mean** and the **median** of the first 1000 integers (so the numbers 1-1000 inclusive).

# %%
import statistics

numbers = list(range(1, 1001))

print(statistics.mean(numbers), statistics.median(numbers))
# Out:
# 500.5 500.5

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: Pub names</h1>
#
# Let's do some data analysis with Python!
#
# We're going to find out what the most common pub name is in the UK.
#
# In the `data` folder is a file containing a database of pubs (originally from https://www.getthedata.com/open-pubs).
#
# 1. First, read its contents into a **list** of rows. How many pubs does the file contain?

# %%
lines = []

with open("data/open_pubs.csv", "r") as f:
    lines = f.readlines()

print(len(lines))
# Out:
# 51331

# %%
lines[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88c8767ad81b> in <cell line: 0>()
# ----> 1 lines[0]
#
# NameError: name 'lines' is not defined

# %% [markdown]
# 2. Look at a single row of your list. Write a function to extract just the **name** of the pub based on a single row.
#
# For example, for the input `"22","Anchor Inn","Upper Street, Stratford St Mary, COLCHESTER","CO7 6LW","604749","234404","51.970379","0.979340","Babergh"` the function should return the string `"Anchor Inn"` (without the extra quotation marks)

# %%
def extract_pub_name(row):
    values = row.split(",")
    return values[1].replace('"', '')

extract_pub_name('"22","Anchor Inn","Upper Street, Stratford St Mary, COLCHESTER","CO7 6LW","604749","234404","51.970379","0.979340","Babergh"')
# Out:
# 'Anchor Inn'

# %% [markdown]
# 3. Create a new empty list and populate it with pub names by using your function on all of the rows in the data.

# %%
pub_names = []

for line in lines:
    pub_names.append(extract_pub_name(line))

print(len(lines), len(pub_names))
# Out:
# 51331 51331

# %%
pub_names[-1]
# Out:
# 'Y Tai'

# %% [markdown]
# 4. At this point, you should have a list containing only the names of the pubs, corresponding to a single column in the original data file.
#
# We want to make sure we treat different versions of the same pub name as the same thing. There is a mix of lower and upper case strings in the file, so we will standardise this.
#
# We will also remove the word "the" so that a pub called "The King's Head" will be treated as having the same name as one that's simply called "King's Head".
#
# Create a new list, this time containing the pub names in **all uppercase** and with the word `"the"` removed.
#
# *Tip: take care not to replace words that **contain** the word `the` like "theatre"*

# %%
uppercase_pubs = []

for name in pub_names:
    upper_name = name.upper()
    uppercase_pubs.append(upper_name.replace("THE ", "")) # the extra space means we don't remove words like "theatre"

print(len(lines), len(uppercase_pubs))
# Out:
# 51331 51331

# %%
uppercase_pubs[-1]
# Out:
# 'Y TAI'

# %% [markdown]
# 5. Now we're ready to count!
#
# Create an empty dictionary to store pub name counts in. The *keys* will be the names themselves, and the *values* will be the number of pubs with that name. The final result will be a bigger version of something like this:
#
# ```python
# {
#     "KING'S HEAD": 47,
#     "BRASENOSE ARMS": 1
# }
# ```
#
# For each pub name you encounter, either:
#
# - add the pub name to the dictionary with a value of 1 (corresponding to the first time we see a pub name)
# - if the pub is already in the dictionary, increment the count of the corresponding key

# %%
pub_counts = {}

for pub_name in uppercase_pubs:
    if pub_name in pub_counts:
        pub_counts[pub_name] += 1
    else:
        pub_counts[pub_name] = 1

pub_counts
# Out:
# {'ANCHOR INN': 69,
#  'ARK BAR RESTAURANT': 1,
#  'BLACK BOY': 10,
#  'BLACK HORSE': 86,
#  'BLACK LION': 31,
#  'BREWERS ARMS': 19,
#  'BRISTOL ARMS': 2,
#  'CAFFEINE LOUNGE': 1,
#  'CARRIERS ARMS': 3,
#  'CHESTNUT TREE FARM': 1,
#  'COCK & BELL': 2,
#  'EIGHT BELLS INN': 2,
#  'FINEZZA PIZZA': 1,
#  'FOX AND HOUNDS': 55,
#  'GLEMSFORD SOCIAL CLUB': 1,
#  'GROVER AND ALLEN - J D WETHERSPOON': 1,
#  'HARE AND HOUNDS': 44,
#  'HINTLESHAM & CHATTISHAM SOCIAL CLUB': 1,
#  'KINGS HEAD': 130,
#  'KINS HEAD INN': 1,
#  'LONG MELFORD INN': 1,
#  'MALDON GREY': 1,
#  'NEEDHAM MARKET BOWLS CLUB': 1,
#  'NORTH STREET TAVERN': 1,
#  'OYSTER REACH BEAFEATER': 1,
#  'PLOUGH & FLEECE': 1,
#  'RED LION': 335,
#  'ROYAL HARWICH YACHT CLUB': 1,
#  'ROYAL OAK': 286,
#  'SHOTLEY VINEYARD': 1,
#  'SILKWORM': 1,
#  'SIX BELLS': 27,
#  'SUDBURY INSTITUTE CLUB': 1,
#  'SUFFOLK CHEFS LTD': 1,
#  'ANGEL GLEMSFORD LTD': 1,
#  'ANGEL INN': 51,
#  'BAY HORSE': 33,
#  'BEAGLE': 3,
#  'BREWERY TAP': 13,
#  'BROOK INN': 5,
#  'BULL': 31,
#  'BUSH INN': 13,
#  'BUTT & OYSTER': 1,
#  'CASE IS ALTERED': 2,
#  'COCK HORSE INN': 1,
#  'COCK INN': 45,
#  'COMFORTABLE COW': 1,
#  'CROWN': 109,
#  'CROWN INN': 199,
#  'EDWARDSTONE WHITE HORSE': 1,
#  'FIVE BELLS': 29,
#  'GARDENERS ARMS': 40,
#  'GEORGE': 61,
#  'GEORGE AND DRAGON INN': 2,
#  'GRANGE': 7,
#  'GREYHOUND': 52,
#  'HARE INN': 1,
#  'HARKSTEAD BAKERS ARMS LTD': 1,
#  'HORSE AND GROOM': 33,
#  'HORSESHOES INN': 4,
#  'LINDSEY ROSE': 1,
#  'LION': 17,
#  'PEACOCK INN': 11,
#  'PRINCE OF WALES PUBLIC HOUSE': 9,
#  'QUEENS HEAD': 127,
#  'ROSE': 7,
#  'ROSE AND CROWN': 108,
#  'ROYAL BRITISH LEGION': 149,
#  'SARACENS HEAD': 20,
#  'SWAN': 82,
#  'SWAN INN': 102,
#  'WHITE HORSE INN': 79,
#  'WHITE HORSE.': 1,
#  'THREE HORSESHOES': 72,
#  'UNITED SERVICES CLUB': 8,
#  'WAGGON AND HORSES': 29,
#  'WHEATSHEAF P.H': 1,
#  'WHEELHOUSE': 3,
#  'WHITE HORSE': 122,
#  'BARLEYLANDS SOCIAL CLUB': 1,
#  'BASILDON & PITSEA CRICKET CLUB': 1,
#  'BASILDON RUGBY FOOTBALL CLUB': 1,
#  'BASILDON SNOOKER CENTRE': 1,
#  'BASILDON SPORTS & LEISURE CLUB': 1,
#  'BASILDON UNITED FOOTBALL CLUB': 1,
#  'BEEHIVE': 30,
#  'BENBOW CLUB': 1,
#  'BEST PARTIES EVER': 1,
#  'BILLERICAY CONSTITUTIONAL CLUB': 1,
#  'BILLERICAY CRICKET CLUB': 1,
#  'BOWERS UTD SPORTS & SOCIAL CLUB BAR': 1,
#  'BRITISH RAIL SOCIAL ASSOCIATION': 1,
#  'CASTLE MAYNE': 1,
#  'CHEQUERS': 51,
#  'CLUB KINGSWOOD': 1,
#  'CROMWELL MANOR/GRAND EVENTS': 1,
#  'CULPEPPER CLUB': 1,
#  'DAVID LLOYD CLUB': 4,
#  'DB SHACK': 1,
#  'DICK TURPIN': 2,
#  'DOWNHAM ARMS': 1,
#  'DUNTON PARK COUNTRY CLUB': 1,
#  'FIREJACKS/ KICK-ASS BURRITO/CHICKEN CARTEL/BARAGARA': 1,
#  'FRENCH MARTINI': 1,
#  'FRYERNS COMMUNITY CENTRE': 1,
#  'FRYERNS SOCIAL CLUB': 1,
#  'GREAT CHALVEDON HALL': 1,
#  'HARVESTER DARBY DIGGER': 1,
#  'HELEN ARBER PERFORMING ARTS': 1,
#  'HOLY CROSS RECREATION GROUND': 1,
#  'INN ON GREEN': 11,
#  'J D WETHERSPOON': 6,
#  'JOLLY FRIAR PUBLIC HOUSE': 1,
#  'KATZ': 1,
#  'MILLER & CARTER': 18,
#  'MOON ON SQUARE': 2,
#  'OWL & PUSSYCAT': 3,
#  'POSH BOYS BREWERY': 1,
#  'POST OFFICE SPORTS CLUB': 2,
#  'Q BALL SNOOKER AND SPORTS BAR': 1,
#  'REIDS BAR': 1,
#  'ROYAL BRITISH LEGION CLUB': 53,
#  'SHEPHERD & DOG': 1,
#  'SPORTZ CLUB BAR': 1,
#  'STOCK BROOK MANOR GOLF CLUB': 1,
#  'BURSTEAD GOLF CLUB': 1,
#  'COACH AND HORSES': 51,
#  'CRANE': 3,
#  'CROWN PUB AND DINING': 1,
#  'DUKE PUBLIC HOUSE': 1,
#  'DUKES HEAD': 19,
#  'EDGE': 1,
#  'FORGE': 6,
#  'FOUR SEASONS PUBLIC HOUSE': 1,
#  'HONEY POT': 1,
#  'NOAK BRIDGE': 1,
#  'PLOUGH AND TRACTOR': 1,
#  'QUAYS': 2,
#  'RAILWAY HOTEL': 44,
#  'WATERMILL': 5,
#  'WOODLANDS CLUB': 2,
#  'UNIT 7': 1,
#  'VANGE & PITSEA SOCIAL CLUB': 1,
#  'WICK BAR': 1,
#  'WICKFORD COMMUNITY ASSOCIATION': 1,
#  'WICKFORD CRICKET CLUB': 1,
#  'WINGED HORSE': 1,
#  'WINSTON SOCIAL CLUB': 1,
#  'ADDISON HOWARD CENTRE': 1,
#  'AFC KEMPSTON ROVERS FOOTBALL CLUB': 1,
#  'ASTONS': 1,
#  'AUCTION ROOM LTD': 1,
#  'BAR CITRUS': 1,
#  'BARLEY MOW': 39,
#  'BEARS & TALES': 1,
#  'BEDFORD & COUNTY GOLF CLUB BAR': 1,
#  'BEDFORD ARMS': 6,
#  'BEDFORD ATHLETIC RUGBY CLUB BAR': 1,
#  'BEDFORD BOROUGH BOWLING CLUB BAR': 1,
#  'BEDFORD ROWING CLUB': 1,
#  'BEDFORD RUGBY (GROUND': 1,
#  'BEDFORD TOWN FOOTBALL CLUB': 1,
#  'BEDFORDSHIRE GOLF CLUB': 1,
#  'BOWORTH SERVICES': 1,
#  'BREWHOUSE AND KITCHEN': 7,
#  'BREWPOINT': 1,
#  'CHEQUERS INN': 47,
#  'CLUB ITALIA': 1,
#  'CLUB POLSKA': 1,
#  'COLMWORTH GOLF CLUB': 1,
#  'COLWORTH CLUB': 1,
#  'DALEYS CLUB': 1,
#  'DEVONSHIRE ARMS': 20,
#  'DOM POLSKI CLUB': 1,
#  'ESQUIRES': 1,
#  'EXECUTIVE SNOOKER CLUB': 1,
#  'FOX & DUCK': 3,
#  'FOX & HOUNDS': 31,
#  'FOX INN': 56,
#  'FUELERS BAR': 1,
#  'GEORGE & DRAGON': 41,
#  'GREYFRIARS SNOOKER CENTRE': 1,
#  'HALF MOON': 29,
#  'HORSE & JOCKEY': 28,
#  'KALOOKI CLUB': 1,
#  'KEMPSTON CONSTITUTIONAL CLUB': 1,
#  'KEMPSTON HAMMERS SPORTS & SOCIAL CLUB': 1,
#  'KEMPSTON PARK INDOOR BOWLS CLUB': 1,
#  'KENT ARMS': 1,
#  'KING WILLIAM IV': 21,
#  'KINGS ARMS': 157,
#  'KINGS ARMS PH': 2,
#  'MECCA BINGO LTD': 2,
#  'MELTIS SPORTS AND SOCIAL CLUB': 1,
#  'MILE ROAD CLUB': 1,
#  'MILL THEATRE': 1,
#  'MIST BEDFORD (SHISHA': 1,
#  'NORTH END CLUB': 1,
#  'OAKLEY SPORTS AND SOCIAL CLUB': 1,
#  'OURS': 2,
#  'PAVENHAM PARK GOLF CLUB': 1,
#  'PILGRIMS PROGRESS': 1,
#  'PODINGTON CRICKET CLUB': 1,
#  'PODINGTON UNITED SERVICES CLUB': 1,
#  'POLHILL ARMS PUB': 1,
#  'PRIDE OF POLAND LIMITED': 1,
#  'RAFA CLUB': 13,
#  'RUSSELL PARK SOCIAL CLUB': 1,
#  'SHIP': 40,
#  "SIX'S": 1,
#  'SLUG & LETTUCE BEDFORD': 1,
#  'SPORT FOR BEDFORD LTD': 1,
#  'SPORTING TARGETS LTD': 1,
#  'STEWARTBY SPORTS & SOCIAL CLUB': 1,
#  'SWAN WITH TWO NICKS': 1,
#  'T BAR': 1,
#  'TAVI BAR AND INDIAN GRILL': 1,
#  'ANCHOR': 30,
#  'BALLOON': 2,
#  'BEAR': 13,
#  'BEDFORD CLUB': 1,
#  'BEDFORD CLUB RESTAURANT': 1,
#  'BEDFORD GOLF CLUBHOUSE': 1,
#  'BELL': 59,
#  'BLUEBELL': 7,
#  'BURNABY ARMS': 1,
#  'CASTLE': 27,
#  'CROSS KEYS': 75,
#  'CROWN AT WILLINGTON': 1,
#  'DUKE INN': 1,
#  'FALCON INN': 19,
#  'FLOWERPOT': 1,
#  'FLUTE': 1,
#  'FORESTERS ARMS': 38,
#  'KITCHEN': 3,
#  'MILL': 11,
#  'MULBERRY BUSH': 3,
#  'MUNTJAC': 1,
#  'NEW INN': 181,
#  'NEW SPORTSMAN': 1,
#  'OAKLEY ARMS': 1,
#  'PARK': 4,
#  'PRINCE OF WALES': 106,
#  'QUEEN PH': 1,
#  'ROYAL GEORGE': 20,
#  'SMITHS ARMS PUBLIC HOUSE LTD': 1,
#  'STAR INN': 85,
#  'STUDIO CLUB': 1,
#  'SUN INN': 88,
#  'THREE COMPASSES': 7,
#  'THREE CRANES': 4,
#  'TIGER MOTH': 3,
#  'VICTORIA ARMS': 9,
#  'WHITE HORSE PUBLIC HOUSE': 8,
#  'WOOLPACK': 23,
#  'THREE CUPS PUB': 1,
#  'THREE TUNS': 41,
#  'VOGUE': 1,
#  'WELLINGTON ARMS PH': 1,
#  'WELLS & CO': 1,
#  'WEST INDIAN CULTURAL & SOCIAL SOCIETY': 1,
#  'YE THREE FYSHES': 1,
#  'ZINC NIGHTCLUB': 1,
#  '47 BAR & RESTAURANT': 1,
#  'BALTIC AMBER': 1,
#  'BIRDBROOK BOWLS CLUB': 1,
#  'BLACK NOTLEY VILLAGE HALL CLUB': 1,
#  'BOCKING ARTS THEATRE': 1,
#  'BOCKING SPORTS CLUB': 1,
#  'BOCKING UNITED SERVICES CLUB': 1,
#  'BRADWELL VILLAGE HALL': 1,
#  'BRAINTREE AND BOCKING CONSTITUTIONAL CLUB': 1,
#  'BRAINTREE BOWLS CLUB': 1,
#  'BRAINTREE HOCKEY CLUB': 1,
#  'BRAINTREE RUGBY CLUB': 1,
#  'BRAINTREE TOWN FOOTBALL CLUB': 1,
#  'BRAINTREE': 1,
#  'CAESAR AT DOLPHIN': 1,
#  'CASTLE HEDINGHAM BOWLS CLUB': 1,
#  'COGGESHALL CONSERVATIVE CLUB': 1,
#  'COGGESHALL TOWN CRICKET CLUB': 1,
#  'COGGESHALL TOWN FOOTBALL CLUB': 1,
#  'COLNE VALLEY GOLF CLUB': 1,
#  'COLNES CONSTITUTIONAL CLUB': 1,
#  'COURTAULD HALSTEAD BOWLS CLUB': 1,
#  'COURTYARD TAP': 1,
#  'CRITTALL ATHLETIC SOCIAL CLUB': 1,
#  'DEAN FIERHELLER T/A WOOLPACK INN': 1,
#  'EARLS COLNE RECREATION CLUB': 1,
#  'EARLS COLNE ATLAS SOCIAL CLUB': 1,
#  'EASTERFORD LODGE MASONIC HALL': 1,
#  'GOSFIELD SOCIAL CLUB': 1,
#  'HALSTEAD CONSERVATIVE CLUB': 1,
#  'HALSTEAD CRICKET CLUB': 1,
#  'HALSTEAD MASONIC HALL': 1,
#  'HATFIELD PEVEREL FOOTBALL CLUB': 1,
#  'HAVERHILL GOLF CLUB': 1,
#  'HELIONS BUMPSTEAD SPORTS PAVILLION CLUB': 1,
#  'IL SALICE': 1,
#  'KELVEDON CONSERVATIVE CLUB': 1,
#  'KELVEDON LABOUR CLUB': 1,
#  'KING WILLIAM IV PH': 1,
#  'LITTLE ELMS PH': 1,
#  'MDP WETHERSFIELD AMENITIES': 1,
#  "O'GRADY'S": 1,
#  'RAF ASSOCIATION HEADQUARTERS': 1,
#  'ROYAL BRITISH LEGION MEMORIAL HALL': 1,
#  'SIBLE HEDINGHAM SPORTS AND SOCIAL CLUB': 1,
#  'SILVER END BOWLING CLUB': 1,
#  'SILVER END UNITED FOOTBALL CLUB': 1,
#  'SIR CHARLIE LOCKRAMS DRINKING PARLOUR': 1,
#  'SOCIAL WHITE HORSE': 1,
#  'STEEPLE BUMPSTEAD BOWLS CLUB': 1,
#  'STEPFIELD SNOOKER CLUB': 1,
#  'SWAN INN PH': 2,
#  'TERLING CRICKET CLUB': 1,
#  'ANGEL PH': 2,
#  'BATTESFORD COURT': 1,
#  'BELL INN': 102,
#  'BULL PH': 3,
#  'CHAPEL INN': 1,
#  'CHERRY TREE': 21,
#  'COMPASSES AT PATTISWICK': 1,
#  'CO-OPERATIVE FOOD': 1,
#  'CROSS KEYS PH': 2,
#  'DORRINGTON': 1,
#  'DRUM INN': 3,
#  'DUKE OF WELLINGTON': 40,
#  'EIGHT BELLS PH': 2,
#  'FIVE BELLS PH': 1,
#  'GEORGE INN': 68,
#  'GREEN DRAGON': 37,
#  'GREEN MAN': 45,
#  'HARE AND HOUNDS PH': 2,
#  'HENNY SWAN': 1,
#  'HORSE AND GROOM PH': 1,
#  'KAVERN': 1,
#  'KINGS HEAD PH': 3,
#  'LAMARSH LION': 1,
#  'LION PH': 1,
#  'LOCOMOTIVE': 4,
#  'LOUNGE': 10,
#  'MULBERRY TREE': 3,
#  'NAGS HEAD': 70,
#  'ONLEY': 1,
#  'ORANGE TREE': 14,
#  'PHEASANT PH': 2,
#  'PICTURE PALACE': 2,
#  'PINKUAH ARMS': 1,
#  'PLOUGH': 88,
#  'RAILWAY': 32,
#  'RAILWAY TAVERN': 56,
#  'RED LION INN': 45,
#  'RED LION PH': 3,
#  'RETREAT PH': 1,
#  'SPORTSMAN': 31,
#  'SQUARE AND COMPASSES': 1,
#  'SWISS BELL': 1,
#  'THREE BOTTLES': 1,
#  'THREE TUNS INN': 9,
#  'VICTORY INN': 7,
#  'VINE BAR AND GRILL': 2,
#  'WELSH PRINCESS': 1,
#  'WETHERSFIELD CLUB': 1,
#  'WHEATSHEAF': 103,
#  'WHITE HART': 167,
#  'WHITE HORSE PH': 3,
#  'WOOLPACK INN': 14,
#  'THREE PIGEONS': 6,
#  'TWINSTEAD CRICKET CLUB': 1,
#  'WESTERN ARMS': 1,
#  'WHISPERS WINE BAR': 1,
#  'WHITE NOTLEY FOOTBALL CLUB': 1,
#  'WITHAM BOWLS CLUB': 1,
#  'WITHAM CRICKET CLUB': 1,
#  'WITHAM HOCKEY CLUB': 1,
#  'WITHAM LEGION MESS': 1,
#  'WITHAM RUGBY CLUB': 1,
#  'WITHAM TOWN FOOTBALL AND SOCIAL CLUB': 1,
#  "ARNIE'S": 1,
#  'ATTLEBOROUGH FOOTBALL CLUB': 2,
#  'ATTLEBOROUGH SNOOKER CENTRE': 1,
#  'BANHAM BARREL': 1,
#  'BEDINGFELD ARMS': 1,
#  'BRECKLAND LODGE (STAG)': 1,
#  'CHERRY TREE PUBLIC HOUSE': 4,
#  'DARBYS': 1,
#  'DCS BAR': 1,
#  'DEREHAM GOLF CLUB': 1,
#  'DEREHAM MASONIC CLUB': 1,
#  'GEMINI PUBLIC HOUSE': 1,
#  'GOLD LEAF CATERING': 1,
#  'GOYMOUR PROPERTIES - APPLEWOOD HALL': 1,
#  'GRESSENHALL SOCIAL CLUB': 1,
#  'GREYHOUND INN': 54,
#  'GUILDHALL AND CARNEGIE COMPLEX': 1,
#  'HARLING RECREATION BOWLS CLUB': 1,
#  'HORSE & GROOM': 11,
#  'ICE': 1,
#  'J D WETHERSPOON LTD': 1,
#  'KINGS HEAD HOTEL': 21,
#  'LONDON TAVERN': 3,
#  'MATTISHALL SPORTS & SOCIAL CLUB': 1,
#  'MILLWRIGHTS ARMS': 1,
#  'NO.19': 1,
#  'OLD BELL PUBLIC HOUSE': 3,
#  'OX & PLOUGH': 2,
#  "RY'S BAR AND GRILL": 1,
#  'SAHAM TONEY FOOTBALL CLUB': 1,
#  'SHIP INN': 140,
#  "SHROPHAM VILLAGE SOCIAL CLUB (SAYER'S BAR)": 1,
#  'STANLEYÂ€™S PAD': 1,
#  'SWAFFHAM CONSERVATIVE CLUB': 1,
#  'ALBION': 25,
#  'ANGEL': 20,
#  'BAR (WELLS COLE COMMUNITY CENTRE)': 1,
#  'BLUE LION PUB': 1,
#  'BULL INN': 48,
#  'CHASE': 3,
#  'COACHMAKERS ARMS': 7,
#  'COCK': 5,
#  'EAGLE': 20,
#  'FLYING FISH': 2,
#  'FOX': 30,
#  'GAMEKEEPER': 2,
#  'GARDEN HOUSE PUBLIC HOUSE': 1,
#  'GOLDEN DOG': 1,
#  'GREAT DANES COUNTRY INN': 1,
#  'GREENSTONE': 1,
#  "KING'S ARMS": 8,
#  'LITCHAM BULL': 1,
#  'LODGE': 7,
#  'MASONIC HALL': 42,
#  'METRO': 2,
#  'OLD RAILWAY TAVERN': 1,
#  'OLD WORKHOUSE BAR': 1,
#  'OLDE WINDMILL INN': 1,
#  'PLOUGHSHARE': 1,
#  'PLOUGHSHARE (FARM SHOP': 1,
#  'RAILWAY ARMS': 7,
#  'ROYAL STANDARD': 21,
#  'SAXON PUBLIC HOUSE': 1,
#  'SQUIRRELS DREY': 1,
#  'STATION BAR & RESTAURANT': 1,
#  'VICTORIA INN': 42,
#  'WARRENER': 1,
#  'WHITE HART FREE HOUSE': 1,
#  'WILLOW HOUSE': 1,
#  'WINDMILL': 34,
#  'THETFORD & DISTRICT EX-SERVICE & SOCIAL CLUB': 1,
#  'THETFORD CONSERVATIVE CLUB LTD': 1,
#  'THETFORD TOWN FOOTBALL CLUB': 1,
#  'TOFTWOOD SOCIAL CENTRE': 1,
#  'TWENTY CHURCHWARDENS': 1,
#  'WAGGON & HORSES PUBLIC HOUSE': 1,
#  'WOODSIDE SNOOKER CENTRE': 2,
#  '124 (ESSEX) TRANSPORT SQUADRON RLC ARMY RESERVE CENTRE': 1,
#  'ABBOTSWICK COTTAGE': 1,
#  'BAPTIST CHURCH': 3,
#  'BARDSWELL SOCIAL CLUB (BAR ONLY)': 1,
#  'BENTLEY CRICKET CLUB': 1,
#  'BENTLEY DISTRICT VILLAGE CLUB': 1,
#  'BLACKMORE SPORTS AND SOCIAL CLUB': 1,
#  'BLADES - SOCIETY OF OLD BRENTWOOD SPORTS CLUB': 1,
#  'BRAVE NELSON': 1,
#  'BRENTWOOD COUNTY CRICKET CLUB (CHATS)': 1,
#  'BRENTWOOD GOLF CLUB': 1,
#  'BRENTWOOD HARD COURT TENNIS CLUB': 1,
#  'BRENTWOOD RUGBY CLUB': 1,
#  'BRENTWOOD TENNIS CLUB': 1,
#  'BRENTWOOD THEATRE': 1,
#  'BROOKWEALD CRICKET CLUB': 1,
#  'CHARLIES BAR LTD': 1,
#  'CHRIST CHURCH HALL': 1,
#  'DAIRYMAN': 1,
#  'ESSEX ARMS': 2,
#  'GEORGE INNS LTD': 1,
#  'GREAT DANES YOUTH FOOTBALL CLUB': 1,
#  'HARTSWOOD GOLF CLUB': 1,
#  'HERONGATE ATHLETIC FOOTBALL CLUB': 1,
#  'HERONGATE CRICKET CLUB': 1,
#  'HOLLANDS WINE BAR': 1,
#  'HUTTON ALL SAINTS SCOUT GROUP': 1,
#  'HUTTON CRICKET CLUB( WINDMILL GROUND)': 1,
#  'HUTTON FOOTBALL CLUB': 1,
#  'INGATESTONE & FRYERNING COMMUNITY ASSOCIATION': 1,
#  'INGATESTONE BOWLING CLUB': 1,
#  'KELVEDON HATCH SENIOR CITIZEN LUNCH CLUB': 1,
#  'KINGS CHASE SPORTS AND SOCIAL CLUB LTD': 1,
#  'LUNCHEON CLUB': 1,
#  'MAVERICKS RFC': 1,
#  'MOUNT AVENUE BANQUETING SUITE': 1,
#  'NAVESTOCK CRICKET CLUB': 1,
#  'OLDE DOG INN': 1,
#  "O'NEILLS": 17,
#  'PRINCE ALBERT': 23,
#  'PROVOCATIVE LOUNGE': 1,
#  'RENDEZVOUS AT PILGRIMS HALL': 1,
#  'RUMOURS': 6,
#  'SHENFIELD CRICKET CLUB': 1,
#  'SLUG & LETTUCE': 22,
#  'SOUTH WEALD CRICKET CLUB': 1,
#  'SOUTH WEALD PARISH HALL': 1,
#  'SUGAR HUT': 1,
#  'THATCHERS ARMS': 3,
#  'BOARS HEAD (HERONGATE)': 1,
#  'BRICKLAYERS ARMS': 27,
#  'CHOUGH PUBLIC HOUSE': 1,
#  'CRICKETERS': 36,
#  'GEORGE AND DRAGON': 50,
#  'HALFWAY HOUSE': 32,
#  'HERMIT CLUB': 1,
#  'HUTTON JUNCTION': 1,
#  'LEATHER BOTTLE': 8,
#  'MERCHANT': 6,
#  'OLD GREEN DRAGON': 1,
#  'RISING SUN': 79,
#  'ROBIN': 3,
#  'SHEPHERD': 1,
#  'SOUTH ESSEX GOLF CLUB': 1,
#  'SPREAD EAGLE': 28,
#  'TERISS BAR': 1,
#  'VINE BRENTWOOD': 1,
#  'WHITE HORSE (WET SIDE ONLY)': 1,
#  'THRIFTWOOD SCOUT CAMPSITE': 1,
#  'TIPPS CROSS REMEMBRANCE HALL': 1,
#  'TOBY CARVERY': 37,
#  'VAULT': 10,
#  'VIRGIN ACTIVE CLEARVIEW': 1,
#  'WARLEY PARK GOLF CLUB': 1,
#  'AYLSHAM EX SERVICE & SOCIAL C': 1,
#  'BLACK BOYS PUBLIC HOUSE': 2,
#  'BLACK LION PUBLIC HOUSE': 3,
#  'BLACK SWAN PUBLIC HOUSE': 2,
#  'BLUE BOAR INN AND STREET FLAVOURS': 1,
#  'BRICK KILNS PUBLIC HOUSE': 1,
#  'BUCKINGHAMSHIRE ARMS': 1,
#  'COUNTY ARTS BOWLS CLUB': 1,
#  'CROWN PUBLIC HOUSE': 10,
#  'DRAYTON LEISURE CENTRE CLUB': 1,
#  'EARLE ARMS INN': 1,
#  "FATSO'S": 1,
#  'GORDON PUBLIC HOUSE': 1,
#  'GREEN MAN PUBLIC HOUSE (TFI RACKHEATH) -ARDYN HOLDINGS': 1,
#  'KINGS ARMS PUBLIC HOUSE': 9,
#  'KINGS HEAD INN': 11,
#  'KINGS HEAD PUBLIC HOUSE': 14,
#  'LONGE ARMS WET SALES': 1,
#  'LORD NELSON PUBLIC HOUSE': 5,
#  'MAIDS HEAD PUBLIC HOUSE': 1,
#  'MARSHAM ARMS INN': 1,
#  'NORFOLK BROADS YACHT CLUB': 1,
#  'OTTER PUBLIC HOUSE': 1,
#  'RACECOURSE CASTLE CARVERY': 1,
#  'RANWORTH MALTSTERS': 1,
#  'RECRUITING SERGEANT': 2,
#  'RED LION (DRAYTON': 1,
#  'RED LION PUBLIC HOUSE': 18,
#  'REEDCUTTER PUBLIC HOUSE': 1,
#  'REEDHAM FERRY INN': 1,
#  'REEDHAM VIKINGS SOCIAL CLUB': 1,
#  'RISING SUN PUBLIC HOUSE': 4,
#  'ROSE & CROWN (WET SALES ONLY)': 1,
#  'ROUNDWOOD FUNCTION & CONFERENCE CENTRE': 1,
#  'RUSHCUTTERS ARMS': 1,
#  'SAINTS EVENT VENUE': 1,
#  'SHOULDER OF MUTTON PUBLIC HOUSE': 1,
#  'SILVER FOX PUBLIC HOUSE (WET SALES ONLY)': 1,
#  'SOLE & HEEL': 1,
#  'TAMARIND INDIAN RESTAURANT': 1,
#  'ACLE BRIDGE INN': 1,
#  'BRIDGE INN': 53,
#  'CANTLEY COCK': 1,
#  'CHEQUERS HAINFORD': 1,
#  'CHESTNUT TREE': 8,
#  'COTTAGE PUBLIC HOUSE': 1,
#  'DIAL HOUSE': 1,
#  'DOG INN': 16,
#  'FEATHERS PUBLIC HOUSE': 4,
#  'FOX PUBLIC HOUSE': 2,
#  'FUR & FEATHER INN': 1,
#  'GAS SOCIAL CLUB': 1,
#  'HONINGHAM BUCK LTD': 1,
#  'PLOUGH INN': 130,
#  'RAM INN': 6,
#  'RED LION WET SALES ONLY': 1,
#  'RIVERGARDEN': 1,
#  'SHIP PUBLIC HOUSE': 6,
#  'YARE PUBLIC HOUSE': 1,
#  'TOWN HOUSE HOTEL': 1,
#  'UNICORN PUBLIC HOUSE': 3,
#  'WHIFFLER PUBLIC HOUSE': 1,
#  'WOODMAN PUBLIC HOUSE-WET SALES': 1,
#  'WROXHAM FOOTBALL CLUB': 1,
#  'BOGDAN CATERING': 1,
#  'BRITISH LEGION': 9,
#  'BROXBOURNE SPORTS CLUB': 1,
#  'BROXBOURNE YOUTH FOOTBALL CLUB': 1,
#  'CHESHUNT COMMUNITY SPORTS PARK': 1,
#  'CHESHUNT FOOTBALL CLUB': 1,
#  'CHESHUNT PARK GOLF CLUB(PRIVATE)': 1,
#  'CHESHUNT ROYAL BRITISH LEGION CLUB': 1,
#  'GALLEY HALL': 1,
#  'GOFFS OAK COMRADES CLUB': 1,
#  'HODDESDON LABOUR CLUB': 1,
#  'J D WETHERSPOON STAR': 1,
#  'MERKUR CASHINO': 4,
#  "O'SHEA IRISH BAR": 1,
#  'RYE PARK & HODDESDON UNITED SERVICES': 1,
#  'RYE PARK CONSERVATIVE CLUB': 1,
#  'STANBOROUGHS CONSERVATIVE CLUB': 1,
#  'BELL HOTEL  (INCLUDING B&B)': 1,
#  'BULLS HEAD': 71,
#  'COACH HOUSE': 12,
#  'CROCODILE': 1,
#  'FREEMASONS': 4,
#  'GOFFS OAK': 1,
#  'GOLDEN LION': 70,
#  'MALTSTERS PUBLIC HOUSE': 1,
#  'MOON AND CROSS': 1,
#  'OLD ANCHOR PUBLIC HOUSE': 1,
#  'OLD ENGLISH GENTLEMAN': 4,
#  'OLD STAR': 2,
#  'RED COW': 15,
#  'ROMAN URN(NO FOOD PREPARED)': 1,
#  'SUN': 9,
#  'VINE PUBLIC HOUSE': 1,
#  'WHEATSHEAF PH AND ACCOMODATION': 1,
#  'WHITE BEAR PUBLIC HOUSE': 2,
#  'WHITE SWAN': 80,
#  'WINDMILL PUBLIC HOUSE': 6,
#  'UKRANIAN SOCIAL CLUB': 4,
#  'WORMLEY SPORTS CLUB': 1,
#  'ADMIRAL CASINO': 10,
#  'BALLARE': 1,
#  'BARON OF BEEF': 1,
#  'BAROOSH': 1,
#  'BOATHOUSE PUBLIC HOUSE': 1,
#  'CASTLE INN': 54,
#  'CHAMPION OF THAMES': 1,
#  'CHERRY HINTON CONSTITUTIONAL CLUB': 1,
#  'CHESTERTON MENS CLUB': 1,
#  'CLARENDON ARMS': 2,
#  'DE LUCA CUCINA & BAR': 1,
#  'EARL OF BEACONSFIELD': 1,
#  'EARL OF DERBY': 2,
#  'EATING INN': 1,
#  'FEZ CLUB': 1,
#  'FORT ST GEORGE': 1,
#  'FREE PRESS PH': 1,
#  'HIDDEN ROOMS': 1,
#  "HUDSON'S ALE HOUSE": 1,
#  'KING STREET RUN P.H.': 1,
#  'KINGSTON ARMS': 2,
#  'LIVE AND LET LIVE': 2,
#  'LOLA LO': 3,
#  'LORD BYRON INN': 1,
#  'NEWNHAM CROFT SOCIAL CLUB': 1,
#  'OLD SPRING PUBLIC HOUSE': 1,
#  'OTHERSYDE LTD': 1,
#  'PANTON ARMS': 2,
#  'PARTYMAN WORLD OF PLAY': 1,
#  'PRINCE REGENT': 4,
#  'QUEEN EDITH PUBLIC HOUSE': 1,
#  'SALISBURY ARMS': 4,
#  'SALISBURY CONSERVATIVE CLUB': 3,
#  'SIR ISAAC NEWTON': 2,
#  'STOLEN': 1,
#  'TA BOUCHE': 1,
#  'ALEXANDRA ARMS': 3,
#  'ALMA': 10,
#  'ANCHOR PUBLIC HOUSE': 3,
#  'ARCHITECT': 1,
#  'BATH HOUSE': 2,
#  'BLUE MOON': 2,
#  'BROOK': 4,
#  'BURLEIGH ARMS': 1,
#  'CAMBRIDGE BLUE': 1,
#  'CAMBRIDGE BREW HOUSE': 1,
#  'CARLTON ARMS PUBLIC HOUSE': 1,
#  'CARPENTERS ARMS': 43,
#  'CORNER HOUSE': 11,
#  'DOBBLERS INN': 1,
#  'DUKE OF CAMBRIDGE': 7,
#  'EAGLE PUBLIC HOUSE': 7,
#  'ELM TREE': 7,
#  'EMPEROR': 2,
#  'EMPRESS': 5,
#  'FLYING PIG': 2,
#  'GELDART': 1,
#  'GOLDEN HIND': 4,
#  'GRAIN AND HOP STORE': 1,
#  'GRANTA': 1,
#  'GRAPES': 34,
#  'HAWKS CLUB': 1,
#  'JUNCTION': 13,
#  'MAYPOLE P.H.': 1,
#  'MED': 1,
#  'MILTON ARMS': 4,
#  'MITRE PUBLIC HOUSE': 2,
#  'PETERSFIELD': 1,
#  'PICKEREL INN': 2,
#  'PORTLAND ARMS': 7,
#  'PUNTER': 2,
#  'RATHMORE CLUB': 1,
#  'RED BULL': 5,
#  'REGAL': 2,
#  'ROCK': 6,
#  'SNUG': 6,
#  'STATION TAVERN': 2,
#  'TRAM DEPOT': 1,
#  'WATERMAN': 1,
#  'WRESTLERS': 2,
#  'THIRSTY': 1,
#  'TRAVELLER REST': 1,
#  'UNIVERSITY PITT CLUB': 1,
#  "WT'S SPORTS BAR LTD": 1,
#  'BENFLEET CONSERVATIVE CLUB': 1,
#  'BENFLEET TAVERN': 1,
#  'BENFLEET YACHT CLUB': 1,
#  'BOYCE HILL GOLF & COUNTRY CLUB': 1,
#  'BREAD AND CHEESE': 1,
#  'CANVEY CLUB': 1,
#  'CANVEY CRICKET CLUB': 1,
#  'CANVEY ISLAND CONSERVATIVE CLUB': 1,
#  'CANVEY ISLAND FOOTBALL CLUB': 1,
#  'CANVEY ISLAND RUGBY UNION FC': 1,
#  'CANVEY ISLAND SOCIAL CLUB': 1,
#  'CASTLE HOTEL PUBLIC HOUSE': 1,
#  'CASTLE POINT GOLF CLUB': 1,
#  'CHOCOTIYEH': 1,
#  "FATTY'S BAR": 1,
#  'HADLEIGH & THUNDERSLEY CRICKET CLUB': 1,
#  'HADLEIGH CONSERVATIVE CLUB': 1,
#  'HALF CROWN PUBLIC HOUSE': 1,
#  'HAYSTACK': 1,
#  'HOY AND HELMET': 1,
#  'ISLAND YACHT CLUB': 1,
#  'LOBSTER SMACK': 1,
#  'MOTOWNS LOUNGE BAR': 1,
#  'OYSTER BAY SPORTS & WINE BAR': 1,
#  'RACK EM UP': 1,
#  'RILEYS SPORTS BAR': 3,
#  'RIO BINGO CLUB': 1,
#  'SAKS CAFE BAR': 1,
#  'SOUTH BENFLEET SOCIAL CLUB': 1,
#  'MONICO': 1,
#  'WOODMANS ARMS': 3,
#  'THORNEY BAY BAR & RESTAURANT': 1,
#  'WESTERN DANCE CENTRE': 1,
#  'WHITE HART PUBLIC HOUSE': 6,
#  "WINDJAMMER'S UPPER DECK": 1,
#  'ZACH WILLSHER': 1,
#  'ACE CATERERS': 1,
#  'AMPTHILL & DISTRICT RUGBY UNION FOOTBALL CLUB': 1,
#  'AMPTHILL TOWN FOOTBALL CLUB': 1,
#  'ARLESEY SOCIAL CLUB LTD': 1,
#  'ARLESEY TOWN FOOTBALL CLUB': 1,
#  'ASPLEY GUISE & WOBURN SANDS GOLF CLUB LTD': 1,
#  'BARTON BOWLS CLUB': 1,
#  'BARTON ROVERS FOOTBALL CLUB': 1,
#  'BIGGLESWADE RUF & ASSOCIATED CLUBS': 1,
#  'BIGGLESWADE TOWN CRICKET CLUB': 1,
#  'BIGGLESWADE UNITED FOOTBALL CLUB': 1,
#  'BIGGLESWADE UNITED WORKING MENS CLUB': 1,
#  'BIRD IN HAND': 34,
#  'CADDINGTON GOLF CLUB': 1,
#  'CADDINGTON SPORTS & SOCIAL CLUB': 1,
#  "CRANFIELD STUDENTS' ASSOCIATION": 1,
#  'CRANFIELD UNITED FOOTBALL CLUB': 1,
#  "DROVER'S ARMS": 1,
#  'DUNSTABLE CONSERVATIVE CLUB': 1,
#  'DUNSTABLE RUGBY UNION FOOTBALL CLUB': 1,
#  'DUNSTABLE TOWN CRICKET CLUB': 1,
#  'ENGINE & TENDER': 1,
#  'FAIRFIELD BOWLS CLUB': 1,
#  'FLITWICK BOWLS CLUB': 1,
#  'FLITWICK CRICKET CLUB': 1,
#  'FLUTTERS LEISURE LTD': 1,
#  'FLYING FOX': 1,
#  'GARY COOPER': 1,
#  'GURKHA KITCHEN CRANFIELD UK LTD/SWAN': 1,
#  'ICKWELL CRICKET CLUB': 1,
#  "JOHN O'GAUNT GOLF CLUB": 1,
#  'JOLLY COOPERS': 3,
#  'LANGFORD FOOTBALL CLUB': 1,
#  'LEIGHTON BUZZARD GOLF CLUB LIMITED': 1,
#  'LONGS INN': 1,
#  'OLD HUNTERS LODGE (WHIPSNADE) LTD': 1,
#  'SOUTH BEDFORDSHIRE GOLF CLUB': 1,
#  'SPICE LOUNGE': 1,
#  'STEWARTBY WATER SPORTS CLUB LTD': 1,
#  'STOTFOLD FOOTBALL CLUB': 1,
#  'STUDHAM SPORTS & SOCIAL CLUB': 1,
#  'AXE & COMPASS': 1,
#  'BLACKBIRDS': 2,
#  'BRIDGE': 14,
#  'BUCKINGHAM ARMS': 2,
#  'BUMBLE BEE': 2,
#  'COCK INN (BROOM) LTD': 1,
#  'COMPASSES': 4,
#  'CORNERSTONE': 2,
#  'CRAFT UNION PUB COMPANY LTD': 3,
#  'CROWN HOTEL': 42,
#  'DUKES': 2,
#  'ENGINEERS ARMS': 3,
#  'EWE & LAMB': 2,
#  'FANCOTT ARMS': 1,
#  'FARMERS BOY': 2,
#  'FLYING HORSE': 12,
#  'FOUR HORSEMEN': 2,
#  'FRENCH HORN': 3,
#  'FROG & RHUBARB': 1,
#  'GLIDER': 1,
#  'GLOBE': 29,
#  'GOLDEN BELL': 1,
#  'GUINEA': 2,
#  'HARE & HOUNDS': 34,
#  'HEATH INN': 1,
#  'KINGS REACH': 1,
#  'KNIFE & CLEAVER': 1,
#  'MANOR': 4,
#  'MARKET CROSS': 3,
#  'MILLBROOK GOLF CLUB LTD': 1,
#  'MUSGRAVE ARMS': 1,
#  'ODDFELLOWS ARMS': 32,
#  'OLD FARM INN': 1,
#  'OLD OAK': 7,
#  'OLD SUGAR LOAF': 1,
#  'OLD SUN INN': 2,
#  'OSSORY ARMS': 1,
#  'PHEASANT INN': 22,
#  'PICTURE HOUSE': 7,
#  'POYNTERS ARMS': 1,
#  'ROSE & CROWN': 65,
#  'ROSE INN': 20,
#  'STAG': 14,
#  'STAR': 30,
#  'STAR & GARTER': 6,
#  'SUGAR LOAF': 4,
#  'THORNTON ARMS': 2,
#  'TRUE BRITON': 2,
#  'VANILLA ALTERNATIVE LTD': 1,
#  'VICTORIA': 45,
#  'WEATHERCOCK INN AND OUT': 1,
#  'WHITE LION': 71,
#  'WINGFIELD CLUB LTD': 1,
#  'YORKSHIRE GREY': 4,
#  'TILSWORTH GOLF CENTRE LTD': 1,
#  'WESTONING RECREATION CLUB': 1,
#  'AUZORA LOUNGE': 1,
#  'BAKERS ARMS': 14,
#  'BAR 7': 3,
#  'BAR AND BEYOND': 4,
#  'BAR VINO LTD': 1,
#  'BARESITO': 1,
#  'BE AT ONE': 25,
#  'BURGER BRATS @WHITE HORSE': 1,
#  'CHELMER INN': 1,
#  'CHELMSFORD CONSERVATIVE CLUB': 1,
#  'CHELMSFORD GOLF CLUB LTD': 1,
#  'CLAY PIGEON PUB': 1,
#  'CLUB BAR AND GRILL @ CLUB WOODHAM': 1,
#  'CLUB TANTALIZE': 1,
#  'EAGLE AND HIND': 1,
#  'EGO RESTAURANTS HOLDING': 1,
#  'FOX & HOUNDS P H': 1,
#  'FOX & RAVEN': 1,
#  'FOX AND GOOSE': 9,
#  'GALLEYWOOD & DISTRICT SOCIAL CLUB': 1,
#  'GALLEYWOOD CRICKET AND FOOTBALL CLUB': 1,
#  'GALVIN GREEN MAN': 1,
#  'GARDENERS': 1,
#  'GOLDEN FLEECE': 21,
#  'GREAT BADDOW MILLENNIUM COMMUNITY CENTRE': 1,
#  'HOPPILY': 1,
#  'HORSE AND GROOM P H': 1,
#  'HUSTLERS SPORTS BAR': 1,
#  'IVORY PEG': 1,
#  'NEW SPORTS CENTRE': 1,
#  "O'CONNORS": 3,
#  'ODDFELLOWS ARMS SMOKEHOUSE': 1,
#  'OLD CHELMSFORDIANS': 1,
#  'ONE GREEN BOTTLE': 1,
#  'PIE & PINT INNS CASTLE LTD': 1,
#  'POPWORLD': 16,
#  'Q BALLS SNOOKER CENTRE': 1,
#  'QUART POT': 1,
#  'QUEENS HEAD PH': 2,
#  'R A F A CLUB': 2,
#  'RAILWAY PUBLIC HOUSE': 1,
#  'RED BERET': 1,
#  'ROYAL ENGINEERS SOCIAL CLUB': 1,
#  'ROYAL STEAMER': 1,
#  'SANDON SPORTS CLUB': 1,
#  'SIR EVELYN WOOD P.H': 1,
#  'SLUG AND LETTUCE': 38,
#  'SOUTH WOODHAM FERRERS RUGBY': 1,
#  'SPRINGFIELD CRICKET CLUB': 1,
#  'STOCK & BUTTSBURY BOWLING CLUB': 1,
#  'TAP ROOM 19': 1,
#  'ALE HOUSE': 9,
#  'ANCHOR PH': 3,
#  'BARGE INN': 7,
#  'BELL AT RETTENDON': 1,
#  'BLACK BULL': 57,
#  'BOOTMAKER': 1,
#  'CHELMSFORD CLUB': 1,
#  'CRICKETERS INN': 10,
#  'CUCKOO': 6,
#  'CURLEW': 1,
#  'DOG AND PARTRIDGE': 12,
#  'ENDEAVOUR': 2,
#  'FOLLY BISTRO': 1,
#  'GENERALS ARMS': 1,
#  'GRIFFIN': 30,
#  'HARVARD INN': 1,
#  'HAWK': 1,
#  'HOOP': 1,
#  'HUNGRY HORSE (FLYER)': 1,
#  'LION INN': 10,
#  'MOULSHAM TAP': 1,
#  "NAG'S HEAD": 2,
#  'OLD WINDMILL': 3,
#  'ORIGINAL PLOUGH': 1,
#  'PIG AND WHISTLE': 8,
#  'PLOUGH HARVESTER': 1,
#  'RIVERSIDE INN': 9,
#  'RODNEY INN': 1,
#  'ROYAL BRITISH LEGION HALL': 1,
#  'TULIP P H': 1,
#  'TWO SAXONS P.H.': 1,
#  'WALNUT TREE': 14,
#  'WHALEBONE INN': 1,
#  'WINE CELLAR': 2,
#  'TOWN CRIER': 3,
#  'TWO BREWERS': 13,
#  'WALKABOUT': 17,
#  'WHITE BEAR P H': 1,
#  'WOODHAM WATERSPORTS ASS. CLUBHOUSE AND PREMISES': 1,
#  'WRITTLE BOWLING CLUB': 1,
#  'WRITTLE COMMUNITY ASSOCIATION': 1,
#  'ABBERTON & DISTRICT CRICKET CLUB': 1,
#  'ABBEY ARMS': 3,
#  'AFTER OFFICE HOURS': 1,
#  'ATIK': 8,
#  'BELLE VUE SOCIAL CLUB': 1,
#  'BRICKLAYERS': 3,
#  'BUBBLE BLITZ LTD': 1,
#  'BULL HOTEL': 7,
#  'CENTURION': 6,
#  'CHERRY TREE INN': 5,
#  'COLCHESTER SEA CADETS': 1,
#  'CURVE': 2,
#  'DABCHICKS SAILING CLUB': 1,
#  'DOG & PHEASANT': 2,
#  'DONKEY & BUSKINS': 1,
#  'EIGHT ASH GREEN CRICKET CLUB': 1,
#  'FASHION CAFE BAR': 1,
#  'FOUNDRY ARMS': 3,
#  'GOAT & BOOT': 1,
#  'GREENSTEAD ASSOCIATION SOCIAL CLUB': 1,
#  'HIGHWAYS SOCIAL CLUB': 1,
#  'HORSE & GROOM INN': 3,
#  'HOSPITAL ARMS': 1,
#  'LITTLE CROWN': 2,
#  'LIVE & LET LIVE': 1,
#  "MAT'S KITCHEN @ FAT CAT": 1,
#  'MERSEA ISLAND BOWLING CLUB': 1,
#  'NEW TIMES': 1,
#  'NEW TOWN TAVERN': 1,
#  'OLD CROWN INN': 8,
#  'PIES & PUDS ESSEX': 1,
#  'PLAY FOOTBALL LTD': 1,
#  'QUEEN STREET BREWHOUSE': 1,
#  'QUEENS HEAD PUBLIC HOUSE': 7,
#  'ROBERTS CLUB': 1,
#  'ROWHEDGE SOCIAL CLUB': 1,
#  'RUBIX': 2,
#  'ST GILES MASONIC CENTRE': 1,
#  'STRAWS': 1,
#  'SUB ZERO': 1,
#  'ALBERT': 5,
#  'ANCIENT BRITON': 3,
#  'ARTILLERYMAN': 1,
#  'BLACK BUOY INN': 1,
#  'BONNIE BLUE OAK': 1,
#  'BRITISH GRENADIER': 1,
#  'CAMULODUNUM': 1,
#  'CASTLE INN PUBLIC HOUSE': 1,
#  'FRIAR': 1,
#  'LAYER FOX': 1,
#  'ODD ONE OUT': 1,
#  'OFFICERS CLUB': 1,
#  'PELDON ROSE INN': 1,
#  'PLAYHOUSE': 2,
#  'PRETTYGATE': 1,
#  'PURPLE DOG': 1,
#  'RED DOG CAFE': 1,
#  'ROYAL MORTAR': 1,
#  ...}

# %% [markdown]
# 6. Using the dictionary you've just created, find the **most common pub name**. This will be the *key* that corresponds to the highest *value* in the dictionary.
#
# *Hint: as you go through the `items` in the dictionary, keep track of the highest count and replace it every time you encounter a higher one. Be sure to also track the corresponding key, so you know which pub name the highest count belongs to!*

# %%
top_count = 0
most_popular_pub = ""

for pub, count in pub_counts.items():
    if count > top_count:
        most_popular_pub = pub
        top_count = count

print(most_popular_pub, top_count)
# Out:
# RED LION 335

# %% [markdown]
# *BONUS: can you solve the counting part using something from the `collections` module?*
#
# **https://docs.python.org/3/library/collections.html**

# %%
from collections import Counter

Counter(uppercase_pubs)
# Out:
# Counter({'RED LION': 335,
#          'ROYAL OAK': 286,
#          'CROWN INN': 199,
#          'NEW INN': 181,
#          'WHITE HART': 167,
#          'KINGS ARMS': 157,
#          'ROYAL BRITISH LEGION': 149,
#          'SHIP INN': 140,
#          'KINGS HEAD': 130,
#          'PLOUGH INN': 130,
#          'QUEENS HEAD': 127,
#          'WHITE HORSE': 122,
#          'CROWN': 109,
#          'ROSE AND CROWN': 108,
#          'PRINCE OF WALES': 106,
#          'WHEATSHEAF': 103,
#          'SWAN INN': 102,
#          'BELL INN': 102,
#          'RAILWAY INN': 89,
#          'SUN INN': 88,
#          'PLOUGH': 88,
#          'BLACK HORSE': 86,
#          'STAR INN': 85,
#          'SWAN': 82,
#          'WHITE SWAN': 80,
#          'WHITE HORSE INN': 79,
#          'RISING SUN': 79,
#          'CROSS KEYS': 75,
#          'THREE HORSESHOES': 72,
#          'BULLS HEAD': 71,
#          'WHITE LION': 71,
#          'NAGS HEAD': 70,
#          'GOLDEN LION': 70,
#          'MASONS ARMS': 70,
#          'ANCHOR INN': 69,
#          'GEORGE INN': 68,
#          'ROSE & CROWN': 65,
#          'GEORGE': 61,
#          'BELL': 59,
#          'BLACK BULL': 57,
#          'FOX INN': 56,
#          'RAILWAY TAVERN': 56,
#          'FOX AND HOUNDS': 55,
#          'GREYHOUND INN': 54,
#          'CASTLE INN': 54,
#          'WHITE HART INN': 54,
#          'ROYAL BRITISH LEGION CLUB': 53,
#          'BRIDGE INN': 53,
#          'GREYHOUND': 52,
#          'BUTCHERS ARMS': 52,
#          'WHEATSHEAF INN': 52,
#          'ANGEL INN': 51,
#          'CHEQUERS': 51,
#          'COACH AND HORSES': 51,
#          'GEORGE AND DRAGON': 50,
#          'TRAVELLERS REST': 50,
#          'BULL INN': 48,
#          'BLACK SWAN': 48,
#          'CHEQUERS INN': 47,
#          'VILLAGE INN': 47,
#          'LAMB INN': 46,
#          'COCK INN': 45,
#          'GREEN MAN': 45,
#          'RED LION INN': 45,
#          'VICTORIA': 45,
#          'FARMERS ARMS': 45,
#          'HARE AND HOUNDS': 44,
#          'RAILWAY HOTEL': 44,
#          'CARPENTERS ARMS': 43,
#          'BLACK HORSE INN': 43,
#          'MASONIC HALL': 42,
#          'VICTORIA INN': 42,
#          'CROWN HOTEL': 42,
#          'LORD NELSON': 42,
#          'GEORGE & DRAGON': 41,
#          'THREE TUNS': 41,
#          'GARDENERS ARMS': 40,
#          'SHIP': 40,
#          'DUKE OF WELLINGTON': 40,
#          'BARLEY MOW': 39,
#          'STATION HOTEL': 39,
#          'GLOBE INN': 39,
#          'FORESTERS ARMS': 38,
#          'SLUG AND LETTUCE': 38,
#          'COACH & HORSES': 38,
#          'ROYAL OAK INN': 38,
#          'ALL BAR ONE': 38,
#          'GREEN DRAGON': 37,
#          'TOBY CARVERY': 37,
#          'DUKE OF YORK': 37,
#          'RED LION HOTEL': 37,
#          'BLACKSMITHS ARMS': 37,
#          'BLUE BELL INN': 37,
#          'CRICKETERS': 36,
#          'BLUE BELL': 35,
#          'BRITANNIA INN': 35,
#          'WINDMILL': 34,
#          'GRAPES': 34,
#          'BIRD IN HAND': 34,
#          'HARE & HOUNDS': 34,
#          'MINERS ARMS': 34,
#          'BAY HORSE': 33,
#          'HORSE AND GROOM': 33,
#          'CROSS KEYS INN': 33,
#          'RAILWAY': 32,
#          'HALFWAY HOUSE': 32,
#          'ODDFELLOWS ARMS': 32,
#          'BUZZ BINGO': 32,
#          'BLACK LION': 31,
#          'BULL': 31,
#          'FOX & HOUNDS': 31,
#          'SPORTSMAN': 31,
#          'BEEHIVE': 30,
#          'ANCHOR': 30,
#          'FOX': 30,
#          'STAR': 30,
#          'GRIFFIN': 30,
#          'FOUNTAIN INN': 30,
#          'CONSERVATIVE CLUB': 30,
#          'HALF MOON INN': 30,
#          'FIVE BELLS': 29,
#          'WAGGON AND HORSES': 29,
#          'HALF MOON': 29,
#          'GLOBE': 29,
#          'QUEENS ARMS': 29,
#          'SEVEN STARS': 29,
#          'HORSE & JOCKEY': 28,
#          'SPREAD EAGLE': 28,
#          'ROBIN HOOD': 28,
#          'JOINERS ARMS': 28,
#          'SHOULDER OF MUTTON': 28,
#          'SIX BELLS': 27,
#          'CASTLE': 27,
#          'BRICKLAYERS ARMS': 27,
#          'BLACK BULL INN': 27,
#          'GEORGE HOTEL': 26,
#          'REVOLUTION': 26,
#          'ALBION': 25,
#          'BE AT ONE': 25,
#          'QUEENS HOTEL': 25,
#          'BOAT INN': 24,
#          'PHOENIX': 24,
#          'HORSE AND JOCKEY': 24,
#          'VICTORIA HOTEL': 24,
#          'WOOLPACK': 23,
#          'PRINCE ALBERT': 23,
#          'WELLINGTON': 23,
#          'MARKET TAVERN': 23,
#          'CRICKETERS ARMS': 23,
#          'MALT SHOVEL': 23,
#          'SLUG & LETTUCE': 22,
#          'PHEASANT INN': 22,
#          'PLUME OF FEATHERS': 22,
#          'TAVERN': 22,
#          'BAY HORSE INN': 22,
#          'KING WILLIAM IV': 21,
#          'CHERRY TREE': 21,
#          'KINGS HEAD HOTEL': 21,
#          'ROYAL STANDARD': 21,
#          'GOLDEN FLEECE': 21,
#          'WOODMAN': 21,
#          'JOLLY SAILOR': 21,
#          'VINE': 21,
#          'GATE INN': 21,
#          'WINDMILL INN': 21,
#          'WELLINGTON INN': 21,
#          'COMMERCIAL HOTEL': 21,
#          'SARACENS HEAD': 20,
#          'DEVONSHIRE ARMS': 20,
#          'ROYAL GEORGE': 20,
#          'ANGEL': 20,
#          'EAGLE': 20,
#          'ROSE INN': 20,
#          'KINGS ARMS HOTEL': 20,
#          'VINE INN': 20,
#          'COMMERCIAL INN': 20,
#          'ROYAL HOTEL': 20,
#          'UNION INN': 20,
#          'BREWERS ARMS': 19,
#          'DUKES HEAD': 19,
#          'FALCON INN': 19,
#          'ROBIN HOOD INN': 19,
#          'BEAR INN': 19,
#          'WAGGON & HORSES': 19,
#          'ROYAL': 19,
#          'DOLPHIN INN': 19,
#          'MILLER & CARTER': 18,
#          'RED LION PUBLIC HOUSE': 18,
#          'TURKS HEAD': 18,
#          'HORSESHOE INN': 18,
#          'PEACOCK': 18,
#          'BEEHIVE INN': 18,
#          'STAG INN': 18,
#          'NAVIGATION INN': 18,
#          'CHURCH INN': 18,
#          'CASTLE HOTEL': 18,
#          'BOOT INN': 18,
#          'LION': 17,
#          "O'NEILLS": 17,
#          'WALKABOUT': 17,
#          'HARVESTER': 17,
#          'LAMB': 17,
#          'CROOKED BILLET': 17,
#          'TALBOT INN': 17,
#          'SWAN HOTEL': 17,
#          'DOLPHIN': 17,
#          'HOLE IN WALL': 17,
#          'GRIFFIN INN': 17,
#          'JUNCTION INN': 17,
#          'MITRE': 17,
#          'WETHERSPOONS': 17,
#          'DOG INN': 16,
#          'POPWORLD': 16,
#          'OAK': 16,
#          'THREE CROWNS': 16,
#          'STATION': 16,
#          'ROEBUCK': 16,
#          'OLD CROWN': 16,
#          'WHITE HART HOTEL': 16,
#          'PUNCH BOWL': 16,
#          'PACK HORSE': 16,
#          'CROWN AND ANCHOR': 16,
#          'COLLIERS ARMS': 16,
#          'OLD HOUSE AT HOME': 16,
#          'RED COW': 15,
#          'WOODMAN INN': 15,
#          'MECCA BINGO': 15,
#          'PLOUGH AND HARROW': 15,
#          'THREE HORSE SHOES': 15,
#          'STATION INN': 15,
#          'YEW TREE INN': 15,
#          'UNICORN INN': 15,
#          'ROEBUCK INN': 15,
#          'BREWDOG': 15,
#          'LONDON INN': 15,
#          'STAGS HEAD': 15,
#          'CENTRAL BAR': 15,
#          'FLEECE INN': 15,
#          'WHITE LION HOTEL': 15,
#          'VICTORIA BAR': 15,
#          'ORANGE TREE': 14,
#          'WOOLPACK INN': 14,
#          'KINGS HEAD PUBLIC HOUSE': 14,
#          'BRIDGE': 14,
#          'STAG': 14,
#          'BAKERS ARMS': 14,
#          'WALNUT TREE': 14,
#          'YATES': 14,
#          'BOATHOUSE': 14,
#          'MARQUIS OF GRANBY': 14,
#          'CROSS INN': 14,
#          'BRITANNIA': 14,
#          'BLUE ANCHOR': 14,
#          'ALBION INN': 14,
#          'BREWERY TAP': 13,
#          'BUSH INN': 13,
#          'RAFA CLUB': 13,
#          'BEAR': 13,
#          'JUNCTION': 13,
#          'TWO BREWERS': 13,
#          'FOUNTAIN': 13,
#          'BUCK INN': 13,
#          'FIGHTING COCKS': 13,
#          'VOLUNTEER INN': 13,
#          'MASONIC LODGE': 13,
#          'FALCON': 13,
#          'WHITE BEAR': 13,
#          'TOP HOUSE': 13,
#          'VENUE': 13,
#          'WHEATSHEAF HOTEL': 13,
#          'BOARS HEAD': 13,
#          'WELCOME INN': 13,
#          'SPORTSMAN INN': 13,
#          'TALBOT': 13,
#          'HEAD OF STEAM': 13,
#          'PARK INN': 13,
#          'CHURCH HOUSE INN': 13,
#          'COTTAGE INN': 13,
#          'COACH HOUSE': 12,
#          'FLYING HORSE': 12,
#          'DOG AND PARTRIDGE': 12,
#          'ROYAL OAK PUBLIC HOUSE': 12,
#          'WISHING WELL': 12,
#          'MARKET INN': 12,
#          'COOPERS ARMS': 12,
#          'RAVEN': 12,
#          'DUN COW': 12,
#          'BULLS HEAD INN': 12,
#          'TIGER INN': 12,
#          'CROWN & ANCHOR': 12,
#          'ELEPHANT AND CASTLE': 12,
#          'RISING SUN INN': 12,
#          'CROSS KEYS HOTEL': 12,
#          'RING O BELLS': 12,
#          'PEACOCK INN': 11,
#          'INN ON GREEN': 11,
#          'MILL': 11,
#          'HORSE & GROOM': 11,
#          'KINGS HEAD INN': 11,
#          'CORNER HOUSE': 11,
#          'ROYAL BRITISH LEGION CLUB LTD': 11,
#          'HOLLY BUSH': 11,
#          'QUEEN VICTORIA': 11,
#          'WHEEL INN': 11,
#          'PAVILION': 11,
#          'PARK TAVERN': 11,
#          'OLD RED LION': 11,
#          'BUILDERS ARMS': 11,
#          'EIGHT BELLS': 11,
#          'DURHAM OX': 11,
#          'ALMA INN': 11,
#          'WELLINGTON HOTEL': 11,
#          'WHITE LION INN': 11,
#          'BROWN COW': 11,
#          'QUEENS HEAD HOTEL': 11,
#          'JOLLY FARMER': 11,
#          'HORSESHOE': 11,
#          'STAR AND GARTER': 11,
#          'GOOSE': 11,
#          'VAULTS': 11,
#          'WINDSOR CASTLE': 11,
#          'QUEENS': 11,
#          'GREY HORSE': 11,
#          'PLOUGH & HARROW': 11,
#          'ROYAL EXCHANGE': 11,
#          'AULD HOOSE': 11,
#          'BLACK BOY': 10,
#          'LOUNGE': 10,
#          'VAULT': 10,
#          'CROWN PUBLIC HOUSE': 10,
#          'ADMIRAL CASINO': 10,
#          'ALMA': 10,
#          'CRICKETERS INN': 10,
#          'LION INN': 10,
#          'WHITE HOUSE': 10,
#          'VOLUNTEER': 10,
#          'WHITE HORSE HOTEL': 10,
#          'FEATHERS': 10,
#          'FERRY INN': 10,
#          'EXCHANGE': 10,
#          'BLUE BOAR': 10,
#          'HIGHWAYMAN': 10,
#          'PEAR TREE INN': 10,
#          'GROVE': 10,
#          'HOLLYBUSH': 10,
#          'NORTH STAR': 10,
#          'UNICORN': 10,
#          'WHITE SWAN INN': 10,
#          'MILL INN': 10,
#          'MOON UNDER WATER': 10,
#          'APPLE TREE': 10,
#          'ROYAL OAK HOTEL': 10,
#          'SMUGGLERS INN': 10,
#          'DOG AND GUN': 10,
#          'CHESHIRE CHEESE': 10,
#          'SHAKESPEARE': 10,
#          'BLACK DOG': 10,
#          'SALUTATION INN': 10,
#          'MOUNT PLEASANT INN': 10,
#          'SHAKESPEARE INN': 10,
#          'OLD SWAN': 10,
#          'ALEXANDRA': 10,
#          'BLACK BULL HOTEL': 10,
#          'HOPE AND ANCHOR': 10,
#          'SPOTTED COW': 10,
#          'HARBOUR INN': 10,
#          'EAGLE INN': 10,
#          'OLD INN': 10,
#          'PRINCE OF WALES PUBLIC HOUSE': 9,
#          'VICTORIA ARMS': 9,
#          'THREE TUNS INN': 9,
#          'KINGS ARMS PUBLIC HOUSE': 9,
#          'BRITISH LEGION': 9,
#          'SUN': 9,
#          'FOX AND GOOSE': 9,
#          'ALE HOUSE': 9,
#          'RIVERSIDE INN': 9,
#          'MIDLAND HOTEL': 9,
#          'BOOT': 9,
#          'CATHERINE WHEEL': 9,
#          'YEW TREE': 9,
#          'GATE': 9,
#          'JOLLY FARMERS': 9,
#          'SWAN PUBLIC HOUSE': 9,
#          'IVY HOUSE': 9,
#          'TALLY HO': 9,
#          'RED HOUSE': 9,
#          'BROADWAY': 9,
#          'OLD POST OFFICE': 9,
#          'BOWLING GREEN': 9,
#          'RAILWAY CLUB': 9,
#          'HOLLY BUSH INN': 9,
#          'HARROW INN': 9,
#          'BANK': 9,
#          'OLD BANK': 9,
#          'FLEECE': 9,
#          'STUMBLE INN': 9,
#          'HOGARTHS': 9,
#          'COUNTING HOUSE': 9,
#          'CROWS NEST': 9,
#          'GOLDEN CROSS': 9,
#          'BRASS MONKEY': 9,
#          'IMPERIAL': 9,
#          'COMMERCIAL': 9,
#          'SMITHS ARMS': 9,
#          'COUNTY HOTEL': 9,
#          'LION HOTEL': 9,
#          'ROCK INN': 9,
#          'PARK HOTEL': 9,
#          'GRAPES INN': 9,
#          'STATION BAR': 9,
#          'TRAVELLERS INN': 9,
#          'UNITED SERVICES CLUB': 8,
#          'WHITE HORSE PUBLIC HOUSE': 8,
#          "KING'S ARMS": 8,
#          'LEATHER BOTTLE': 8,
#          'CHESTNUT TREE': 8,
#          'PIG AND WHISTLE': 8,
#          'ATIK': 8,
#          'OLD CROWN INN': 8,
#          'OLD MILL': 8,
#          'QUEENS HEAD INN': 8,
#          'BAR': 8,
#          'FORRESTERS ARMS': 8,
#          'WINE BAR': 8,
#          'COMRADES CLUB': 8,
#          'GOALS SOCCER CENTRE': 8,
#          'FERRY BOAT INN': 8,
#          'OLD SHIP': 8,
#          'RETREAT': 8,
#          'MOLLY MALONES': 8,
#          'ALBERT INN': 8,
#          'GOAT INN': 8,
#          'RUNNING HORSE': 8,
#          'FREEMASONS ARMS': 8,
#          'PHEASANT': 8,
#          'OLD SHIP INN': 8,
#          'WELLINGTON ARMS': 8,
#          'J D WETHERSPOON PLC': 8,
#          'DOG HOUSE': 8,
#          'MALLARD': 8,
#          "QUEEN'S HEAD": 8,
#          'ELEPHANT & CASTLE': 8,
#          'HOPE & ANCHOR': 8,
#          'GOLDEN EAGLE': 8,
#          'SEVEN STARS INN': 8,
#          'COURTYARD': 8,
#          'PACK HORSE INN': 8,
#          'CORNER PIN': 8,
#          'WHARF INN': 8,
#          'BUNCH OF GRAPES': 8,
#          'LORD RAGLAN': 8,
#          'PILOT': 8,
#          'WINNING POST': 8,
#          'HOP POLE': 8,
#          'BLACK HORSE HOTEL': 8,
#          'HORSE SHOE INN': 8,
#          'FOX AND HOUNDS INN': 8,
#          'SUN HOTEL': 8,
#          'STANLEY ARMS': 8,
#          'EAGLE AND CHILD': 8,
#          'CITY ARMS': 8,
#          'DERBY ARMS': 8,
#          'GROVE INN': 8,
#          'WYNDHAM ARMS': 8,
#          'BRIDGEND INN': 8,
#          'GRANGE': 7,
#          'ROSE': 7,
#          'BREWHOUSE AND KITCHEN': 7,
#          'BLUEBELL': 7,
#          'THREE COMPASSES': 7,
#          'VICTORY INN': 7,
#          'COACHMAKERS ARMS': 7,
#          'LODGE': 7,
#          'RAILWAY ARMS': 7,
#          'DUKE OF CAMBRIDGE': 7,
#          'EAGLE PUBLIC HOUSE': 7,
#          'ELM TREE': 7,
#          'PORTLAND ARMS': 7,
#          'OLD OAK': 7,
#          'PICTURE HOUSE': 7,
#          'BARGE INN': 7,
#          'BULL HOTEL': 7,
#          'QUEENS HEAD PUBLIC HOUSE': 7,
#          'SPOTTED DOG': 7,
#          'SHED': 7,
#          'OLD BULLS HEAD': 7,
#          'BRIDGE HOUSE': 7,
#          'COUNTRYMAN': 7,
#          'FEATHERS INN': 7,
#          'PLOUGH PUBLIC HOUSE': 7,
#          'ELM TREE INN': 7,
#          'SIX BELLS INN': 7,
#          'FOUR HORSESHOES': 7,
#          'GREEN MAN PUBLIC HOUSE': 7,
#          'EAGLE TAVERN': 7,
#          'LOFT': 7,
#          'NELSON': 7,
#          'SQUIRREL': 7,
#          'PRYZM': 7,
#          'DUKE WILLIAM': 7,
#          'RICHMOND ARMS': 7,
#          'DEW DROP INN': 7,
#          'MANOR HOUSE': 7,
#          'ALEXANDRA HOTEL': 7,
#          'GREYHOUND HOTEL': 7,
#          'JUBILEE INN': 7,
#          'WILLIAM IV': 7,
#          'SADDLE INN': 7,
#          'KINGFISHER': 7,
#          'BOTANIST': 7,
#          'BRICKMAKERS ARMS': 7,
#          'MALT SHOVEL INN': 7,
#          'FISHERMANS ARMS': 7,
#          'BLACKSMITH ARMS': 7,
#          'NAGS HEAD INN': 7,
#          'LIGHTHOUSE': 7,
#          'THATCHED HOUSE': 7,
#          'BRIDGE BAR': 7,
#          'TURNPIKE': 7,
#          'HORSESHOE BAR': 7,
#          'DUKE OF EDINBURGH': 7,
#          'BEER HOUSE': 7,
#          'HARE AND HOUNDS INN': 7,
#          'HUNTSMAN': 7,
#          'KINGS': 7,
#          'RAMS HEAD': 7,
#          'LEGENDS': 7,
#          'TOWNHOUSE': 7,
#          'BEACON': 7,
#          'HALFWAY HOUSE INN': 7,
#          'STABLES': 7,
#          'BREWERS FAYRE': 7,
#          'GRAPES HOTEL': 7,
#          'CLUB': 7,
#          'HARP INN': 7,
#          'MOUNT PLEASANT': 7,
#          'BOROUGH ARMS': 7,
#          'BRITISH LEGION CLUB': 7,
#          'COMPASSES INN': 7,
#          'CELLAR BAR': 7,
#          'SLOOP INN': 7,
#          'THREE HORSESHOES INN': 7,
#          'BLACK LION HOTEL': 7,
#          'TREDEGAR ARMS': 7,
#          'J D WETHERSPOON': 6,
#          'FORGE': 6,
#          'BEDFORD ARMS': 6,
#          'THREE PIGEONS': 6,
#          'RUMOURS': 6,
#          'MERCHANT': 6,
#          'RAM INN': 6,
#          'SHIP PUBLIC HOUSE': 6,
#          'WINDMILL PUBLIC HOUSE': 6,
#          'ROCK': 6,
#          'SNUG': 6,
#          'WHITE HART PUBLIC HOUSE': 6,
#          'STAR & GARTER': 6,
#          'CUCKOO': 6,
#          'CENTURION': 6,
#          "YATES'S": 6,
#          'CROWN & SCEPTRE': 6,
#          'GOAT': 6,
#          'OLD BELL': 6,
#          'THREE HORSESHOES PUBLIC HOUSE': 6,
#          'GREEN MAN INN': 6,
#          'GREYHOUND PUBLIC HOUSE': 6,
#          'FLYING DUTCHMAN': 6,
#          'COCK TAVERN': 6,
#          'LAST POST': 6,
#          'VICTORIA TAVERN': 6,
#          'SPORTSMANS ARMS': 6,
#          'BOAT HOUSE': 6,
#          'OFFICE': 6,
#          'HAYWAIN': 6,
#          'MILLERS ARMS': 6,
#          'LAMB AND FLAG': 6,
#          'PHOENIX PUBLIC HOUSE': 6,
#          'WILLOW TREE': 6,
#          'PITCHER & PIANO': 6,
#          'OLD GEORGE': 6,
#          'BLUE BOAR INN': 6,
#          'BOWLING GREEN INN': 6,
#          'REVOLUCION DE CUBA': 6,
#          'WATERFRONT': 6,
#          'VICTORIA BOWLING CLUB': 6,
#          'BLACK HORSE PUBLIC HOUSE': 6,
#          'BLUE LION': 6,
#          'OLD KINGS HEAD': 6,
#          'FARRIERS ARMS': 6,
#          'DOG AND DUCK': 6,
#          'ODDFELLOWS': 6,
#          'REINDEER INN': 6,
#          'MILL HOUSE': 6,
#          'OLD PLOUGH': 6,
#          'DUKE OF YORK PUBLIC HOUSE': 6,
#          'HIGHWAYMAN INN': 6,
#          'MERMAID INN': 6,
#          'TIPSY COW': 6,
#          'WHITE BULL': 6,
#          'HARROW': 6,
#          'OBSERVATORY': 6,
#          'HOWARD ARMS': 6,
#          'WEAVERS ARMS': 6,
#          'TERRACE': 6,
#          'PRINCE OF WALES INN': 6,
#          'OAK TREE INN': 6,
#          'TALBOT HOTEL': 6,
#          'STARTING GATE': 6,
#          'NELSON INN': 6,
#          'FRIENDSHIP INN': 6,
#          'QUEEN ADELAIDE': 6,
#          'DAVID LLOYD LEISURE': 6,
#          'PRINCESS OF WALES': 6,
#          'DUKE': 6,
#          'PILOT INN': 6,
#          'ACORN': 6,
#          'PRINCE': 6,
#          'CLARENCE': 6,
#          'KING WILLIAM': 6,
#          'ROYAL NAVAL ASSOCIATION': 6,
#          'GREAT WESTERN': 6,
#          'PRINCESS ROYAL': 6,
#          'WATERMANS ARMS': 6,
#          'ANTELOPE': 6,
#          'BLACK PRINCE': 6,
#          'MANOR ARMS': 6,
#          'NEW CLUB': 6,
#          'DUKE OF YORK INN': 6,
#          'BOARD INN': 6,
#          'CORNERHOUSE': 6,
#          'VILLAGE TAVERN': 6,
#          'YARD': 6,
#          'PERCY ARMS': 6,
#          'MANOR HOUSE INN': 6,
#          'BLACK COCK INN': 6,
#          'WATERLOO': 6,
#          'ABBEY INN': 6,
#          'CLOCK TOWER': 6,
#          'LAST ORDERS': 6,
#          'PENNY BLACK': 6,
#          'CARTERS ARMS': 6,
#          'EGERTON ARMS': 6,
#          'GREEN ROOM': 6,
#          'SQUIRREL INN': 6,
#          'WAREHOUSE': 6,
#          "RING O' BELLS": 6,
#          'ALBERT HOTEL': 6,
#          'DOG & PARTRIDGE': 6,
#          'POTTING SHED': 6,
#          'THATCHED TAVERN': 6,
#          'CHAPEL HOUSE': 6,
#          'LORD NELSON INN': 6,
#          'RED COW INN': 6,
#          'SOMERSET ARMS': 6,
#          'OAK INN': 6,
#          'MALTHOUSE': 6,
#          'HUNTSMAN INN': 6,
#          'CRAVEN ARMS': 6,
#          'HOLLYBUSH INN': 6,
#          'GREEN DRAGON INN': 6,
#          'GOLDEN LION INN': 6,
#          'VOLUNTEER ARMS': 6,
#          'CROWN BAR': 6,
#          'CAMBRIAN INN': 6,
#          'BROOK INN': 5,
#          'WATERMILL': 5,
#          'COCK': 5,
#          'LORD NELSON PUBLIC HOUSE': 5,
#          'EMPRESS': 5,
#          'RED BULL': 5,
#          'CHERRY TREE INN': 5,
#          'ALBERT': 5,
#          'THREE BLACKBIRDS': 5,
#          'TUDOR ROSE': 5,
#          'TOWN HOUSE': 5,
#          'ANGEL PUBLIC HOUSE': 5,
#          'HORNS': 5,
#          'BARLEY MOW INN': 5,
#          'OXFORD ARMS': 5,
#          'POACHERS POCKET': 5,
#          'BOX': 5,
#          'MALTSTERS ARMS': 5,
#          'COACH AND HORSES PUBLIC HOUSE': 5,
#          'WHEELWRIGHTS ARMS': 5,
#          'CROWN & CUSHION': 5,
#          'COUNTY': 5,
#          'DUCK INN': 5,
#          'GATEHOUSE': 5,
#          'HERON': 5,
#          'LIFEBOAT INN': 5,
#          'SHIP HOTEL': 5,
#          'MAYPOLE': 5,
#          'HOP INN': 5,
#          'BELL PUBLIC HOUSE': 5,
#          'BELL HOTEL': 5,
#          'BELLE VUE': 5,
#          'COOPERS': 5,
#          'POACHER': 5,
#          'MOJO': 5,
#          'MAYFLOWER': 5,
#          'VICTORY': 5,
#          'BULL PUBLIC HOUSE': 5,
#          "WORLD'S END": 5,
#          'HORSESHOES': 5,
#          'WHITE SWAN PUBLIC HOUSE': 5,
#          'DEVONSHIRE': 5,
#          'KEYS': 5,
#          'STAFF OF LIFE': 5,
#          'GAMECOCK': 5,
#          'GREY HORSE INN': 5,
#          'BEES KNEES': 5,
#          'DOVECOTE': 5,
#          'HOP': 5,
#          'YE OLDE RED LION': 5,
#          'VICTORY CLUB': 5,
#          "RING O'BELLS": 5,
#          'GATE HANGS WELL': 5,
#          'MOORINGS': 5,
#          'PRIORY': 5,
#          'CROWN AND CUSHION': 5,
#          'RUTLAND ARMS': 5,
#          'BAR FEVER': 5,
#          'FLOWER POT': 5,
#          'WOODLANDS HOTEL': 5,
#          'BULLS HEAD HOTEL': 5,
#          'WATERLOO INN': 5,
#          'BEACHCOMBER INN': 5,
#          'CHURCHILLS': 5,
#          'DOG AND GUN INN': 5,
#          'RED ADMIRAL': 5,
#          'ROYAL ARMS': 5,
#          'SIR CHARLES NAPIER': 5,
#          'SIR ROBERT PEEL': 5,
#          'BLACKBIRD': 5,
#          'MARQUIS': 5,
#          'ADAM & EVE': 5,
#          'THREE LIONS': 5,
#          'WEST END SOCIAL CLUB': 5,
#          'CASTLE BAR': 5,
#          'BOOT AND SHOE INN': 5,
#          'PENNY FARTHING': 5,
#          'WORLDS END': 5,
#          'PITCHER AND PIANO': 5,
#          'PELICAN': 5,
#          'PEAR TREE': 5,
#          'FIVE BELLS INN': 5,
#          'ROUNDHOUSE': 5,
#          'CAVALIER': 5,
#          'WEAVERS': 5,
#          'BRITISH QUEEN': 5,
#          'GEORGE IV': 5,
#          'NORFOLK ARMS': 5,
#          "O'NEILL'S": 5,
#          'LONDON COCKTAIL CLUB': 5,
#          'NORTHUMBERLAND ARMS': 5,
#          'WINDSOR': 5,
#          'BRITISH OAK': 5,
#          'GOOD INTENT': 5,
#          'YATES WINE LODGE': 5,
#          'CAT & FIDDLE': 5,
#          'SAWYERS ARMS': 5,
#          'CORNER BAR': 5,
#          'REGENT': 5,
#          'SNOOTY FOX': 5,
#          'CROWN AND SCEPTRE': 5,
#          'ALBANY': 5,
#          'RIFLEMAN': 5,
#          'LIBERTINE': 5,
#          'GROSVENOR ARMS': 5,
#          'GREEN TREE': 5,
#          'VULCAN INN': 5,
#          'RIVERSIDE': 5,
#          'JUBILEE': 5,
#          'BUSH': 5,
#          'ELEPHANT': 5,
#          'GUN INN': 5,
#          'WEST END BOWLING CLUB': 5,
#          'BOWLING CLUB': 5,
#          'AVENUE': 5,
#          'ALBION HOTEL': 5,
#          'BLACK DOG INN': 5,
#          'BROWN COW INN': 5,
#          'GOLDEN BALL': 5,
#          'BREWERY INN': 5,
#          'OLIVE TREE': 5,
#          'TAP': 5,
#          'DUKE OF CUMBERLAND': 5,
#          'ARK': 5,
#          'DRUIDS ARMS': 5,
#          'GOLDEN BALL INN': 5,
#          'THREE MARINERS': 5,
#          'MANOR INN': 5,
#          'PUNCHBOWL': 5,
#          'ANGEL HOTEL': 5,
#          'ADMIRAL': 5,
#          'HORNS INN': 5,
#          'MAYPOLE INN': 5,
#          'FLEUR DE LIS': 5,
#          'WALNUT TREE INN': 5,
#          'DOLPHIN HOTEL': 5,
#          'PLANET KIDS CIC': 5,
#          'TROUT INN': 5,
#          'BLUE BALL': 5,
#          'CORNISH ARMS': 5,
#          'ANTELOPE INN': 5,
#          'RING OF BELLS': 5,
#          'BEAUFORT ARMS': 5,
#          'ROSE AND CROWN INN': 5,
#          'OLD SCHOOL HOUSE': 5,
#          'FOX AND GRAPES': 5,
#          'ANCHOR BAR': 5,
#          'THISTLE BAR': 5,
#          'BRIDGE END INN': 5,
#          'HORSESHOES INN': 4,
#          'DAVID LLOYD CLUB': 4,
#          'PARK': 4,
#          'THREE CRANES': 4,
#          'LOCOMOTIVE': 4,
#          'CHERRY TREE PUBLIC HOUSE': 4,
#          'RISING SUN PUBLIC HOUSE': 4,
#          'FEATHERS PUBLIC HOUSE': 4,
#          'MERKUR CASHINO': 4,
#          'FREEMASONS': 4,
#          'OLD ENGLISH GENTLEMAN': 4,
#          'UKRANIAN SOCIAL CLUB': 4,
#          'PRINCE REGENT': 4,
#          'SALISBURY ARMS': 4,
#          'BROOK': 4,
#          'GOLDEN HIND': 4,
#          'MILTON ARMS': 4,
#          'COMPASSES': 4,
#          'MANOR': 4,
#          'SUGAR LOAF': 4,
#          'YORKSHIRE GREY': 4,
#          'BAR AND BEYOND': 4,
#          'WHALEBONE': 4,
#          'BRIDGEWATER ARMS': 4,
#          'CRYSTAL PALACE': 4,
#          'BOAT': 4,
#          'RIFLE VOLUNTEER': 4,
#          'ROBIN HOOD & LITTLE JOHN': 4,
#          'BROWN BEAR': 4,
#          'MALTINGS': 4,
#          'WATERSIDE INN': 4,
#          'COACH AND HORSES INN': 4,
#          'HAND IN HAND': 4,
#          'MILLER & CARTER STEAKHOUSE': 4,
#          'CARLTON': 4,
#          'GROSVENOR': 4,
#          'KING ALFRED': 4,
#          'FLAT': 4,
#          'HUB': 4,
#          'BAR ONE': 4,
#          'BELLE VUE INN': 4,
#          'ROYAL AIR FORCE ASSOCIATION': 4,
#          'GEORGE PUBLIC HOUSE': 4,
#          'GREENHOUSE': 4,
#          'HIGHLANDER': 4,
#          'PLATFORM': 4,
#          'LIGHTHOUSE INN': 4,
#          'BEEHIVE PUBLIC HOUSE': 4,
#          'TEMPLE BAR': 4,
#          'CASTLE PUBLIC HOUSE': 4,
#          'COTTAGE': 4,
#          'GLASS HOUSE': 4,
#          'OAK TREE': 4,
#          'CAVENDISH': 4,
#          'DRAGON': 4,
#          'YARD OF ALE': 4,
#          'BLUE BALL INN': 4,
#          'LION & LAMB': 4,
#          'CROSSWAYS INN': 4,
#          'DOVE INN': 4,
#          'NEW INN PUBLIC HOUSE': 4,
#          'WATERFRONT INN': 4,
#          'ELMS': 4,
#          'POACHERS': 4,
#          'TRAFALGAR': 4,
#          'WARWICK ARMS': 4,
#          'CONSTITUTIONAL CLUB': 4,
#          'LOUNGE BAR': 4,
#          'FARMHOUSE INN': 4,
#          'BADGER': 4,
#          'CAVENDISH ARMS': 4,
#          'DOVE': 4,
#          'PACKHORSE INN': 4,
#          'BLACK BOY INN': 4,
#          'MOULDERS ARMS': 4,
#          'KING OF PRUSSIA': 4,
#          'DUKE OF SUSSEX': 4,
#          'BEERHEADZ': 4,
#          'KING EDWARD VII': 4,
#          'LIBERAL CLUB': 4,
#          'DOG & GUN': 4,
#          'WENTWORTH ARMS': 4,
#          'VILLAGER': 4,
#          'ADMIRAL NELSON': 4,
#          'FOLLY': 4,
#          'PIED BULL': 4,
#          'BULL AND BUSH': 4,
#          'HUNTING LODGE': 4,
#          'ORGAN GRINDER': 4,
#          'CHANDLERS': 4,
#          'COCO': 4,
#          'RIVERSIDE CLUB': 4,
#          'TAP HOUSE': 4,
#          'VIBE': 4,
#          'SILK MILL': 4,
#          'HIDEOUT': 4,
#          'MERLIN': 4,
#          'DRUID INN': 4,
#          'SQUARE AND COMPASS': 4,
#          'BUBBLE INN': 4,
#          'CLUB HOUSE': 4,
#          'FORTESCUE ARMS': 4,
#          'PAVILLION': 4,
#          'HARRINGTON ARMS': 4,
#          'PUNCH BOWL INN': 4,
#          'GRIFFINS HEAD': 4,
#          'RAM': 4,
#          'HUNTERS INN': 4,
#          'ROCK TAVERN': 4,
#          'HUNGRY HORSE': 4,
#          'LANSDOWNE': 4,
#          'WEST END WORKING MENS CLUB': 4,
#          'TAP & SPILE': 4,
#          'BRIDGE TAVERN': 4,
#          'COURT HOUSE': 4,
#          'STAG AND PHEASANT': 4,
#          'BERKELEY ARMS': 4,
#          'TOP CLUB': 4,
#          'MIDLAND': 4,
#          'WHITE BEAR INN': 4,
#          'WILLOW TREE INN': 4,
#          'TALLY HO INN': 4,
#          'CANNON PUBLIC HOUSE': 4,
#          'JOLLY POTTERS': 4,
#          'COSY CLUB': 4,
#          'MARCH HARE': 4,
#          'NEWMARKET': 4,
#          'WALRUS': 4,
#          'PARLOUR': 4,
#          'OLD WHITE HART': 4,
#          'POTTERS': 4,
#          'ROSE & CROWN INN': 4,
#          'FERRY HOUSE INN': 4,
#          "CARPENTER'S ARMS": 4,
#          'VICTORIA CLUB': 4,
#          'FORESTER ARMS': 4,
#          'DEERS LEAP': 4,
#          'TELEGRAPH INN': 4,
#          'POWERLEAGUE FIVES LIMITED': 4,
#          'THREE WISHES': 4,
#          'MILLER AND CARTER': 4,
#          'IRON HORSE': 4,
#          'RED BARN': 4,
#          'J J MOONS': 4,
#          'WHIPPET INN': 4,
#          'SYDNEY ARMS': 4,
#          "BELUSHI'S": 4,
#          'BUCKS HEAD': 4,
#          'DRAFT HOUSE': 4,
#          'PRINCE ARTHUR': 4,
#          'SIMMONS BAR': 4,
#          'PERSEVERANCE': 4,
#          'ROCKET': 4,
#          'BROWNS': 4,
#          'DIRTY MARTINI': 4,
#          "HARRY'S BAR": 4,
#          'CLIFTON ARMS': 4,
#          'STATION HOUSE': 4,
#          'STAG AND HOUNDS': 4,
#          'PHOENIX BAR': 4,
#          'GRAPEVINE': 4,
#          'BEACONSFIELD': 4,
#          'DUKE OF CORNWALL': 4,
#          'WATERSIDE': 4,
#          'SUTTON ARMS': 4,
#          'METROPOLITAN': 4,
#          'VINEYARD': 4,
#          "QUEEN'S ARMS": 4,
#          'ADVENTURE BAR': 4,
#          'HOPE': 4,
#          'ROYAL ALBERT': 4,
#          'DARTMOUTH ARMS': 4,
#          'PIG & WHISTLE': 4,
#          'RAILWAY BELL': 4,
#          'ROCKINGHAM ARMS': 4,
#          'LORD CLYDE': 4,
#          'HARE': 4,
#          'BEDFORD': 4,
#          "MASON'S ARMS": 4,
#          'IRON DUKE': 4,
#          'LAMB & FLAG': 4,
#          'SHAKESPEARE TAVERN': 4,
#          'BOOT AND SHOE': 4,
#          'CLEVELAND ARMS': 4,
#          'MILL HOUSE INN': 4,
#          'MOORCOCK INN': 4,
#          ...})
